# %% [markdown]
# <a href="https://colab.research.google.com/github/ardilalukita14/Magang-Kominfo/blob/main/Text_Mining_Article.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Install Library yang Dibutuhkan**

# %%
# !pip install GoogleNews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.4-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from GoogleNews) (4.6.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from GoogleNews) (2.8.2)
# Collecting dateparser
#   Downloading dateparser-1.1.1-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 16.6 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser->GoogleNews) (2022.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser->GoogleNews) (1.5.1)
# Collecting regex!=2019.02.19,!=2021.8.27,<2022.3.15
#   Downloading regex-2022.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 50.2 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->GoogleNews) (1.15.0)
# Installing collected packages: regex, dateparser, GoogleNews
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
#       Successfully uninstalled regex-2022.6.2
# Successfully installed GoogleNews-1.6.4 dateparser-1.1.1 regex-2022.3.2

# %%
# !pip install pygooglenews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygooglenews
#   Downloading pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 21.7 MB/s
# Collecting feedparser<6.0.0,>=5.2.1
#   Downloading feedparser-5.2.1.zip (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.8 MB/s
# Collecting dateparser<0.8.0,>=0.7.6
#   Downloading dateparser-0.7.6-py2.py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 55.4 MB/s
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->pygooglenews) (2.3.2.post1)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.3.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44952 sha256=20e3c60cf0118810d93d9621a0f8a8e47236bc375fab895ee908a563c6b01a5b
#   Stored in directory: /root/.cache/pip/wheels/29/bf/46/b4a597d435d3aee6c2fa583824897336d65abf13ebe3405b70
# Successfully built feedparser
# Installing collected packages: requests, feedparser, dateparser, beautifulsoup4, pygooglenews
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: dateparser
#     Found existing installation: dateparser 1.1.1
#     Uninstalling dateparser-1.1.1:
#       Successfully uninstalled dateparser-1.1.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed beautifulsoup4-4.11.1 dateparser-0.7.6 feedparser-5.2.1 pygooglenews-0.1.2 requests-2.28.1

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 7.9 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# !pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      |████████████████████████████████| 211 kB 17.0 MB/s
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (7.1.2)
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      |████████████████████████████████| 7.4 MB 42.4 MB/s
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.13)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.28.1)
# Collecting cssselect>=0.9.2
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (5.2.1)
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.2.6)
# Collecting tldextract>=2.0.1
#   Downloading tldextract-3.3.1-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.0 MB/s
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.2.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2.1.0)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.7.1)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=4c0b77c5595a21f91cbadff9c9d8aa23b1d99c937cd7812e6d0d1d31fbfd8950
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3357 sha256=83e6014b26ac441edd57a22e4b9b745aa59d0e70b7dde7d53f0b7738edfa2c1e
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398404 sha256=9abaa8509420709196da29687e7938e02ef843036aaa19beed38d17462ee156c
#   Stored in directory: /root/.cache/pip/wheels/4c/91/46/3c208287b726df325a5979574324878b679116e4baae1af3c3
# Successfully built tinysegmenter feedfinder2 jieba3k
# Installing collected packages: requests-file, tldextract, tinysegmenter, jieba3k, feedfinder2, cssselect, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 tinysegmenter-0.3 tldextract-3.3.1

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)

# %% [markdown]
# ## **Proses Scraping, Stemming, Stop Words Google News**

# %%
# import library 
from pygooglenews import GoogleNews
import csv
from newspaper import Article
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('punkt')
from pprint import pprint
from textblob import TextBlob
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import datetime
import pandas as pd
from time import sleep
#from google.colab import files
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
f = open("stop words.txt", "r")
stopword_list = []
for line in f:
    stripped_line = line.strip()
    line_list = stripped_line.split()
    stopword_list.append(line_list[0])
f.close()

len(stopword_list)
# Out:
# 758

# %%
# Scrapping Function to get google news (title, link)
gn = GoogleNews(lang = 'id',country = 'ID') 
def get_titles(search):
    stories = []

    # setting tanggal
    start_date = datetime.date(2022,7,1)
    end_date = datetime.date(2022,7,16)
    delta = datetime.timedelta(days=1)
    date_list = pd.date_range(start_date, end_date).tolist()
    
    for date in date_list[:-1]:
        result = gn.search(search, from_=date.strftime('%Y-%m-%d'), to_=(date+delta).strftime('%Y-%m-%d'), when = '1d')
        newsitem = result['entries']
   # stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    for item in newsitem:
        url=item.link
        try:
            article = Article(url)
            article.download()
            article.parse()
            story = {
                'Title' : item.title,
                'Read more' : item.link,
                'Time' : item.published,
                'Article' : article.text,
                'Stemming' : stemmer.stem(article.text),
                'WordTokens' :(word_tokenize(stemmer.stem(article.text))),
                'WordsStop' : [w for w in (word_tokenize(stemmer.stem(article.text))) if not w in stopword_list ],
                'TotalKata' : len([w for w in (word_tokenize(stemmer.stem(article.text))) if not w in stopword_list ])
                }
            if article.title=="Are you a robot?" or article.title=="Subscribe to read" :
                continue
            else:
                stories.append(story)
                i=i+1
                print(i,'',article.title)
                sleep(1)
        except:
              pass
        stories.append(story)
        sleep(0)
    return stories

# %%
# Process Summarize Goolge News Article + Sentiment Analysis of Google News
def summarize_artcle(url):
    article = Article(url)
    # Set up 
    article.download()
    article.parse()
    # Download Punkt
    article.download('punkt')
    article.nlp()
    summary = article.summary

    analysis = TextBlob(article.text)
    sentiment_a =""
    if analysis.polarity > 0:
      sentiment_a="positif"
    elif analysis.polarity < 0:
      sentiment_a="negatif"
    else:
       sentiment_a="netral"

    return summary,sentiment_a

# %%
#Function to save a list
def save_dict(topic, number):
    try: 
      dcts = get_titles(topic)
      news_list = []
      for x in range(number):
        dctss = dcts[x]
        url = dctss['Read more']
        try:
          summary_analysis = list(summarize_artcle(url))
          dctss['Sentiment'] = summary_analysis[1]
          dctss['Summary'] = summary_analysis[0]
        except:
          dctss['Sentiment'] = 'error'
          dctss['Summary'] ='error'
        news_list.append(dctss)
        pprint(dctss)
      return news_list 
    except:
        print('Please input useable topics, thanks or check this -> https://github.com/kotartemiy/pygooglenews#installation')

# %%
#Function to Save a CSV file
def save_to_csv(news_list):
    labels = ['Time', 'Title', 'Read more','Sentiment','Summary', 'Article', 'Stemming', 'WordTokens', 'WordsStop', 'TotalKata']
    try:
        with open(file, 'w') as f:
            writer = csv.DictWriter(f, fieldnames=labels)
            writer.writeheader()
            for elem in news_list:
                writer.writerow(elem)
        print("Download news_today.csv Sucessfully")
    except IOError:
        print("I/O error")
file = input('Rename file: ')
# Out:
# Rename file: maidi.csv

# %%
# Function to save a txt file

def save_to_txt(news_list):
    n=1
    with open(file_txt, 'w') as f: 
      for item in news_list: 
        f.write('-'*20+str(n)+'-'*20+'\n')
        n+=1
        for key, value in item.items(): 
          f.write('%s:\n %s\n' % (key, value))
    print("Download news_today.txt Sucessfully")
file_txt = input('Rename file: ')
# Out:
# Rename file: maidi.txt

# %%
# Let's run this    
print("Hi, there!")
topic = input('Now Enter your topics to Search or Exit: ')
while topic != 'Exit':
  number = int(input('How many articles you want to search (up to 100)? '))
  news_data = save_dict(topic, number)
  try:
    save_to_txt(news_data)
    save_to_csv(news_data)
  except:
    print("Retry it again!")
  topic = input('Now Enter Your Topics to Search or Exit: ')
print('See you, hope you have a great day! ❤️')
# Out:
# Hi, there!
# Now Enter your topics to Search or Exit: maidi
# How many articles you want to search (up to 100)? 10
# {'Article': 'MADIUN – Wali Kota Madiun Maidi meminta program kerja Ikatan '
#             'Wanita Pengusaha Indonesia (IWAPI) mampu bersinergi dengan '
#             'pemerintah daerah dalam memajukan ekonomi di Kota Madiun. '
#             'Keberadaan IWAPI, juga diharapkan membuka lapangan usaha baru dan '
#             'menjadi payung bagi UMKM yang ada di Kota Pendekar.\n'
#             '\n'
#             'Hal itu disampaikan wali kota saat menghadiri pelantikan dan '
#             'pengukuhan pengurus DPC IWAPI Kota Madiun masa bakti 2021-2026, '
#             'di Aston Hotel, Senin (18/7). Dalam kesempatan itu wali kota '
#             'mengatakan agar organisasi berjalan baik, dibutuhkan kerja keras, '
#             'ikhlas, dan cerdas.\n'
#             '\n'
#             '“IWAPI boleh punya mimpi besar, terobosan-terobosan silahkan '
#             'jangan lupa untuk memayungi UMKM. Di Kota Madiun, UMKM bukan lagi '
#             'Usaha Mikro Kecil dan Menengah, tapi Usaha Maju Kita Mendunia,” '
#             'ungkapnya.\n'
#             '\n'
#             'Tak hanya itu, wali kota juga mengatakan saat ini tantangan IWAPI '
#             'untuk menjadi organisasi yang mampu ikut serta memajukan kota. '
#             'Terobosan baru dibutuhkan untuk mewujudkan harapan yang '
#             'diinginkan wali kota itu.\n'
#             '\n'
#             '“Untuk memajukan kota menjadi tanggung jawab dan tantangan kita '
#             'bersama. Kita harus bisa merubah dan mengikuti perubahan. Jangan '
#             'hanya monoton,” ucapnya.\n'
#             '\n'
#             'Maka dengan itu, Wali Kota Maidi mengharapkan agar IWAPI bersama '
#             'pemerintah daerah mampu bersinergi untuk mewujudkan kemajuan bagi '
#             'kota.\n'
#             '\n'
#             '(Dhevit/kus/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/hadiri-pelantikan-dan-pengukuhan-dpc-iwapi-wali-kota-harap-dukungan-pertumbuhan-ekonomi-kota-madiun/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi minta program kerja ikat wanita '
#              'usaha indonesia iwapi mampu sinergi dengan perintah daerah dalam '
#              'maju ekonomi di kota madiun ada iwapi juga harap buka lapang '
#              'usaha baru dan jadi payung bagi umkm yang ada di kota pendekar '
#              'hal itu sampai wali kota saat hadir lantik dan kukuh urus dpc '
#              'iwapi kota madiun masa bakti 2021-2026 di aston hotel senin 18 7 '
#              'dalam sempat itu wali kota kata agar organisasi jalan baik butuh '
#              'kerja keras ikhlas dan cerdas iwapi boleh punya mimpi besar '
#              'terobos silah jangan lupa untuk payung umkm di kota madiun umkm '
#              'bukan lagi usaha mikro kecil dan tengah tapi usaha maju kita '
#              'dunia ungkap tak hanya itu wali kota juga kata saat ini tantang '
#              'iwapi untuk jadi organisasi yang mampu ikut serta maju kota '
#              'terobos baru butuh untuk wujud harap yang ingin wali kota itu '
#              'untuk maju kota jadi tanggung jawab dan tantang kita sama kita '
#              'harus bisa rubah dan ikut ubah jangan hanya monoton ucap maka '
#              'dengan itu wali kota maidi harap agar iwapi sama perintah daerah '
#              'mampu sinergi untuk wujud maju bagi kota dhevit kus diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun Maidi meminta program kerja Ikatan '
#             'Wanita Pengusaha Indonesia (IWAPI) mampu bersinergi dengan '
#             'pemerintah daerah dalam memajukan ekonomi di Kota Madiun.\n'
#             'Hal itu disampaikan wali kota saat menghadiri pelantikan dan '
#             'pengukuhan pengurus DPC IWAPI Kota Madiun masa bakti 2021-2026, '
#             'di Aston Hotel, Senin (18/7).\n'
#             'Dalam kesempatan itu wali kota mengatakan agar organisasi '
#             'berjalan baik, dibutuhkan kerja keras, ikhlas, dan cerdas.\n'
#             'Tak hanya itu, wali kota juga mengatakan saat ini tantangan IWAPI '
#             'untuk menjadi organisasi yang mampu ikut serta memajukan kota.\n'
#             'Maka dengan itu, Wali Kota Maidi mengharapkan agar IWAPI bersama '
#             'pemerintah daerah mampu bersinergi untuk mewujudkan kemajuan bagi '
#             'kota.',
#  'Time': 'Mon, 18 Jul 2022 09:11:42 GMT',
#  'Title': 'Hadiri Pelantikan dan Pengukuhan DPC IWAPI, Wali Kota Harap '
#           'Dukungan Pertumbuhan Ekonomi Kota Madiun | - madiuntoday',
#  'TotalKata': 103,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'minta',
#                 'program',
#                 'kerja',
#                 'ikat',
#                 'wanita',
#                 'usaha',
#                 'indonesia',
#                 'iwapi',
#                 'mampu',
#                 'sinergi',
#                 'dengan',
#                 'perintah',
#                 'daerah',
#                 'dalam',
#                 'maju',
#                 'ekonomi',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'ada',
#                 'iwapi',
#                 'juga',
#                 'harap',
#                 'buka',
#                 'lapang',
#                 'usaha',
#                 'baru',
#                 'dan',
#                 'jadi',
#                 'payung',
#                 'bagi',
#                 'umkm',
#                 'yang',
#                 'ada',
#                 'di',
#                 'kota',
#                 'pendekar',
#                 'hal',
#                 'itu',
#                 'sampai',
#                 'wali',
#                 'kota',
#                 'saat',
#                 'hadir',
#                 'lantik',
#                 'dan',
#                 'kukuh',
#                 'urus',
#                 'dpc',
#                 'iwapi',
#                 'kota',
#                 'madiun',
#                 'masa',
#                 'bakti',
#                 '2021-2026',
#                 'di',
#                 'aston',
#                 'hotel',
#                 'senin',
#                 '18',
#                 '7',
#                 'dalam',
#                 'sempat',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'kata',
#                 'agar',
#                 'organisasi',
#                 'jalan',
#                 'baik',
#                 'butuh',
#                 'kerja',
#                 'keras',
#                 'ikhlas',
#                 'dan',
#                 'cerdas',
#                 'iwapi',
#                 'boleh',
#                 'punya',
#                 'mimpi',
#                 'besar',
#                 'terobos',
#                 'silah',
#                 'jangan',
#                 'lupa',
#                 'untuk',
#                 'payung',
#                 'umkm',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'umkm',
#                 'bukan',
#                 'lagi',
#                 'usaha',
#                 'mikro',
#                 'kecil',
#                 'dan',
#                 'tengah',
#                 'tapi',
#                 'usaha',
#                 'maju',
#                 'kita',
#                 'dunia',
#                 'ungkap',
#                 'tak',
#                 'hanya',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'kata',
#                 'saat',
#                 'ini',
#                 'tantang',
#                 'iwapi',
#                 'untuk',
#                 'jadi',
#                 'organisasi',
#                 'yang',
#                 'mampu',
#                 'ikut',
#                 'serta',
#                 'maju',
#                 'kota',
#                 'terobos',
#                 'baru',
#                 'butuh',
#                 'untuk',
#                 'wujud',
#                 'harap',
#                 'yang',
#                 'ingin',
#                 'wali',
#                 'kota',
#                 'itu',
#                 'untuk',
#                 'maju',
#                 'kota',
#                 'jadi',
#                 'tanggung',
#                 'jawab',
#                 'dan',
#                 'tantang',
#                 'kita',
#                 'sama',
#                 'kita',
#                 'harus',
#                 'bisa',
#                 'rubah',
#                 'dan',
#                 'ikut',
#                 'ubah',
#                 'jangan',
#                 'hanya',
#                 'monoton',
#                 'ucap',
#                 'maka',
#                 'dengan',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'maidi',
#                 'harap',
#                 'agar',
#                 'iwapi',
#                 'sama',
#                 'perintah',
#                 'daerah',
#                 'mampu',
#                 'sinergi',
#                 'untuk',
#                 'wujud',
#                 'maju',
#                 'bagi',
#                 'kota',
#                 'dhevit',
#                 'kus',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'program',
#                'kerja',
#                'ikat',
#                'wanita',
#                'usaha',
#                'indonesia',
#                'iwapi',
#                'sinergi',
#                'perintah',
#                'daerah',
#                'maju',
#                'ekonomi',
#                'kota',
#                'madiun',
#                'iwapi',
#                'harap',
#                'buka',
#                'lapang',
#                'usaha',
#                'payung',
#                'umkm',
#                'kota',
#                'pendekar',
#                'wali',
#                'kota',
#                'hadir',
#                'lantik',
#                'kukuh',
#                'urus',
#                'dpc',
#                'iwapi',
#                'kota',
#                'madiun',
#                'bakti',
#                '2021-2026',
#                'aston',
#                'hotel',
#                'senin',
#                '18',
#                '7',
#                'wali',
#                'kota',
#                'organisasi',
#                'jalan',
#                'butuh',
#                'kerja',
#                'keras',
#                'ikhlas',
#                'cerdas',
#                'iwapi',
#                'mimpi',
#                'terobos',
#                'silah',
#                'lupa',
#                'payung',
#                'umkm',
#                'kota',
#                'madiun',
#                'umkm',
#                'usaha',
#                'mikro',
#                'usaha',
#                'maju',
#                'dunia',
#                'wali',
#                'kota',
#                'tantang',
#                'iwapi',
#                'organisasi',
#                'maju',
#                'kota',
#                'terobos',
#                'butuh',
#                'wujud',
#                'harap',
#                'wali',
#                'kota',
#                'maju',
#                'kota',
#                'tanggung',
#                'tantang',
#                'rubah',
#                'ubah',
#                'monoton',
#                'wali',
#                'kota',
#                'maidi',
#                'harap',
#                'iwapi',
#                'perintah',
#                'daerah',
#                'sinergi',
#                'wujud',
#                'maju',
#                'kota',
#                'dhevit',
#                'kus',
#                'diskominfo']}
# {'Article': 'MADIUN – Wali Kota Madiun Maidi meminta program kerja Ikatan '
#             'Wanita Pengusaha Indonesia (IWAPI) mampu bersinergi dengan '
#             'pemerintah daerah dalam memajukan ekonomi di Kota Madiun. '
#             'Keberadaan IWAPI, juga diharapkan membuka lapangan usaha baru dan '
#             'menjadi payung bagi UMKM yang ada di Kota Pendekar.\n'
#             '\n'
#             'Hal itu disampaikan wali kota saat menghadiri pelantikan dan '
#             'pengukuhan pengurus DPC IWAPI Kota Madiun masa bakti 2021-2026, '
#             'di Aston Hotel, Senin (18/7). Dalam kesempatan itu wali kota '
#             'mengatakan agar organisasi berjalan baik, dibutuhkan kerja keras, '
#             'ikhlas, dan cerdas.\n'
#             '\n'
#             '“IWAPI boleh punya mimpi besar, terobosan-terobosan silahkan '
#             'jangan lupa untuk memayungi UMKM. Di Kota Madiun, UMKM bukan lagi '
#             'Usaha Mikro Kecil dan Menengah, tapi Usaha Maju Kita Mendunia,” '
#             'ungkapnya.\n'
#             '\n'
#             'Tak hanya itu, wali kota juga mengatakan saat ini tantangan IWAPI '
#             'untuk menjadi organisasi yang mampu ikut serta memajukan kota. '
#             'Terobosan baru dibutuhkan untuk mewujudkan harapan yang '
#             'diinginkan wali kota itu.\n'
#             '\n'
#             '“Untuk memajukan kota menjadi tanggung jawab dan tantangan kita '
#             'bersama. Kita harus bisa merubah dan mengikuti perubahan. Jangan '
#             'hanya monoton,” ucapnya.\n'
#             '\n'
#             'Maka dengan itu, Wali Kota Maidi mengharapkan agar IWAPI bersama '
#             'pemerintah daerah mampu bersinergi untuk mewujudkan kemajuan bagi '
#             'kota.\n'
#             '\n'
#             '(Dhevit/kus/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/hadiri-pelantikan-dan-pengukuhan-dpc-iwapi-wali-kota-harap-dukungan-pertumbuhan-ekonomi-kota-madiun/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi minta program kerja ikat wanita '
#              'usaha indonesia iwapi mampu sinergi dengan perintah daerah dalam '
#              'maju ekonomi di kota madiun ada iwapi juga harap buka lapang '
#              'usaha baru dan jadi payung bagi umkm yang ada di kota pendekar '
#              'hal itu sampai wali kota saat hadir lantik dan kukuh urus dpc '
#              'iwapi kota madiun masa bakti 2021-2026 di aston hotel senin 18 7 '
#              'dalam sempat itu wali kota kata agar organisasi jalan baik butuh '
#              'kerja keras ikhlas dan cerdas iwapi boleh punya mimpi besar '
#              'terobos silah jangan lupa untuk payung umkm di kota madiun umkm '
#              'bukan lagi usaha mikro kecil dan tengah tapi usaha maju kita '
#              'dunia ungkap tak hanya itu wali kota juga kata saat ini tantang '
#              'iwapi untuk jadi organisasi yang mampu ikut serta maju kota '
#              'terobos baru butuh untuk wujud harap yang ingin wali kota itu '
#              'untuk maju kota jadi tanggung jawab dan tantang kita sama kita '
#              'harus bisa rubah dan ikut ubah jangan hanya monoton ucap maka '
#              'dengan itu wali kota maidi harap agar iwapi sama perintah daerah '
#              'mampu sinergi untuk wujud maju bagi kota dhevit kus diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun Maidi meminta program kerja Ikatan '
#             'Wanita Pengusaha Indonesia (IWAPI) mampu bersinergi dengan '
#             'pemerintah daerah dalam memajukan ekonomi di Kota Madiun.\n'
#             'Hal itu disampaikan wali kota saat menghadiri pelantikan dan '
#             'pengukuhan pengurus DPC IWAPI Kota Madiun masa bakti 2021-2026, '
#             'di Aston Hotel, Senin (18/7).\n'
#             'Dalam kesempatan itu wali kota mengatakan agar organisasi '
#             'berjalan baik, dibutuhkan kerja keras, ikhlas, dan cerdas.\n'
#             'Tak hanya itu, wali kota juga mengatakan saat ini tantangan IWAPI '
#             'untuk menjadi organisasi yang mampu ikut serta memajukan kota.\n'
#             'Maka dengan itu, Wali Kota Maidi mengharapkan agar IWAPI bersama '
#             'pemerintah daerah mampu bersinergi untuk mewujudkan kemajuan bagi '
#             'kota.',
#  'Time': 'Mon, 18 Jul 2022 09:11:42 GMT',
#  'Title': 'Hadiri Pelantikan dan Pengukuhan DPC IWAPI, Wali Kota Harap '
#           'Dukungan Pertumbuhan Ekonomi Kota Madiun | - madiuntoday',
#  'TotalKata': 103,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'minta',
#                 'program',
#                 'kerja',
#                 'ikat',
#                 'wanita',
#                 'usaha',
#                 'indonesia',
#                 'iwapi',
#                 'mampu',
#                 'sinergi',
#                 'dengan',
#                 'perintah',
#                 'daerah',
#                 'dalam',
#                 'maju',
#                 'ekonomi',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'ada',
#                 'iwapi',
#                 'juga',
#                 'harap',
#                 'buka',
#                 'lapang',
#                 'usaha',
#                 'baru',
#                 'dan',
#                 'jadi',
#                 'payung',
#                 'bagi',
#                 'umkm',
#                 'yang',
#                 'ada',
#                 'di',
#                 'kota',
#                 'pendekar',
#                 'hal',
#                 'itu',
#                 'sampai',
#                 'wali',
#                 'kota',
#                 'saat',
#                 'hadir',
#                 'lantik',
#                 'dan',
#                 'kukuh',
#                 'urus',
#                 'dpc',
#                 'iwapi',
#                 'kota',
#                 'madiun',
#                 'masa',
#                 'bakti',
#                 '2021-2026',
#                 'di',
#                 'aston',
#                 'hotel',
#                 'senin',
#                 '18',
#                 '7',
#                 'dalam',
#                 'sempat',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'kata',
#                 'agar',
#                 'organisasi',
#                 'jalan',
#                 'baik',
#                 'butuh',
#                 'kerja',
#                 'keras',
#                 'ikhlas',
#                 'dan',
#                 'cerdas',
#                 'iwapi',
#                 'boleh',
#                 'punya',
#                 'mimpi',
#                 'besar',
#                 'terobos',
#                 'silah',
#                 'jangan',
#                 'lupa',
#                 'untuk',
#                 'payung',
#                 'umkm',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'umkm',
#                 'bukan',
#                 'lagi',
#                 'usaha',
#                 'mikro',
#                 'kecil',
#                 'dan',
#                 'tengah',
#                 'tapi',
#                 'usaha',
#                 'maju',
#                 'kita',
#                 'dunia',
#                 'ungkap',
#                 'tak',
#                 'hanya',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'kata',
#                 'saat',
#                 'ini',
#                 'tantang',
#                 'iwapi',
#                 'untuk',
#                 'jadi',
#                 'organisasi',
#                 'yang',
#                 'mampu',
#                 'ikut',
#                 'serta',
#                 'maju',
#                 'kota',
#                 'terobos',
#                 'baru',
#                 'butuh',
#                 'untuk',
#                 'wujud',
#                 'harap',
#                 'yang',
#                 'ingin',
#                 'wali',
#                 'kota',
#                 'itu',
#                 'untuk',
#                 'maju',
#                 'kota',
#                 'jadi',
#                 'tanggung',
#                 'jawab',
#                 'dan',
#                 'tantang',
#                 'kita',
#                 'sama',
#                 'kita',
#                 'harus',
#                 'bisa',
#                 'rubah',
#                 'dan',
#                 'ikut',
#                 'ubah',
#                 'jangan',
#                 'hanya',
#                 'monoton',
#                 'ucap',
#                 'maka',
#                 'dengan',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'maidi',
#                 'harap',
#                 'agar',
#                 'iwapi',
#                 'sama',
#                 'perintah',
#                 'daerah',
#                 'mampu',
#                 'sinergi',
#                 'untuk',
#                 'wujud',
#                 'maju',
#                 'bagi',
#                 'kota',
#                 'dhevit',
#                 'kus',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'program',
#                'kerja',
#                'ikat',
#                'wanita',
#                'usaha',
#                'indonesia',
#                'iwapi',
#                'sinergi',
#                'perintah',
#                'daerah',
#                'maju',
#                'ekonomi',
#                'kota',
#                'madiun',
#                'iwapi',
#                'harap',
#                'buka',
#                'lapang',
#                'usaha',
#                'payung',
#                'umkm',
#                'kota',
#                'pendekar',
#                'wali',
#                'kota',
#                'hadir',
#                'lantik',
#                'kukuh',
#                'urus',
#                'dpc',
#                'iwapi',
#                'kota',
#                'madiun',
#                'bakti',
#                '2021-2026',
#                'aston',
#                'hotel',
#                'senin',
#                '18',
#                '7',
#                'wali',
#                'kota',
#                'organisasi',
#                'jalan',
#                'butuh',
#                'kerja',
#                'keras',
#                'ikhlas',
#                'cerdas',
#                'iwapi',
#                'mimpi',
#                'terobos',
#                'silah',
#                'lupa',
#                'payung',
#                'umkm',
#                'kota',
#                'madiun',
#                'umkm',
#                'usaha',
#                'mikro',
#                'usaha',
#                'maju',
#                'dunia',
#                'wali',
#                'kota',
#                'tantang',
#                'iwapi',
#                'organisasi',
#                'maju',
#                'kota',
#                'terobos',
#                'butuh',
#                'wujud',
#                'harap',
#                'wali',
#                'kota',
#                'maju',
#                'kota',
#                'tanggung',
#                'tantang',
#                'rubah',
#                'ubah',
#                'monoton',
#                'wali',
#                'kota',
#                'maidi',
#                'harap',
#                'iwapi',
#                'perintah',
#                'daerah',
#                'sinergi',
#                'wujud',
#                'maju',
#                'kota',
#                'dhevit',
#                'kus',
#                'diskominfo']}
# {'Article': 'MADIUN – Wali Kota Madiun Maidi terus mendorong pemuda untuk '
#             'meningkatkan kompetensi. Hal ini seperti yang diungkapkan oleh '
#             'orang nomor satu di Kota Pendekar ini saat menghadiri pertemuan '
#             'dengan Karang Taruna, Kelompok Pemuda, Influencer, dan Forum Anak '
#             'Kota Madiun di Kelurahan Taman, Senin (18/7).\n'
#             '\n'
#             '“Anak muda harus berperan dalam pembangunan,” tuturnya.\n'
#             '\n'
#             'Menurut wali kota, Kota Madiun tidak memiliki hasil alam yang '
#             'dapat dimanfaatkan oleh generasi mendatang. Karenanya, bekal yang '
#             'dapat disiapkan adalah ilmu yang bermanfaat.\n'
#             '\n'
#             'Untuk itu, Mantan Sekda Kota Madin tersebut terus memacu pemuda '
#             'agar tak henti belajar. Salah satunya, dengan menguasai '
#             'keterampilan tertentu.\n'
#             '\n'
#             '“Ilmu itu bekal kita di masa depan. Kalau kita banyak ilmu, maka '
#             'ilmu itu yang akan menjaga kita,” jelasnya.\n'
#             '\n'
#             'Pada kesempatan itu, wali kota juga berpesan kepada generasi muda '
#             'untuk berperan serta di dalam pembangunan. Yakni, dengan '
#             'memberikan usulan-usulan yang membangun.\n'
#             '\n'
#             '“Silakan disampaikan. Langsung ke pemkot atau lewat dewan. '
#             'Asalkan disampaikan dengan cara yang baik,” tandasnya. '
#             '(Nanda/irs/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/buka-dialog-bersama-pemuda-taman-wali-kota-dorong-peningkatan-kompetensi-generasi-muda/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi terus dorong pemuda untuk tingkat '
#              'kompetensi hal ini seperti yang ungkap oleh orang nomor satu di '
#              'kota pendekar ini saat hadir temu dengan karang taruna kelompok '
#              'pemuda influencer dan forum anak kota madiun di lurah taman '
#              'senin 18 7 anak muda harus peran dalam bangun tutur turut wali '
#              'kota kota madiun tidak milik hasil alam yang dapat manfaat oleh '
#              'generasi datang karena bekal yang dapat siap adalah ilmu yang '
#              'manfaat untuk itu mantan sekda kota madin sebut terus pacu '
#              'pemuda agar tak henti ajar salah satu dengan kuasa terampil '
#              'tentu ilmu itu bekal kita di masa depan kalau kita banyak ilmu '
#              'maka ilmu itu yang akan jaga kita jelas pada sempat itu wali '
#              'kota juga pesan kepada generasi muda untuk peran serta di dalam '
#              'bangun yakni dengan beri usul yang bangun sila sampai langsung '
#              'ke pemkot atau lewat dewan asal sampai dengan cara yang baik '
#              'tandas nanda irs diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun Maidi terus mendorong pemuda untuk '
#             'meningkatkan kompetensi.\n'
#             'Hal ini seperti yang diungkapkan oleh orang nomor satu di Kota '
#             'Pendekar ini saat menghadiri pertemuan dengan Karang Taruna, '
#             'Kelompok Pemuda, Influencer, dan Forum Anak Kota Madiun di '
#             'Kelurahan Taman, Senin (18/7).\n'
#             'Menurut wali kota, Kota Madiun tidak memiliki hasil alam yang '
#             'dapat dimanfaatkan oleh generasi mendatang.\n'
#             'Kalau kita banyak ilmu, maka ilmu itu yang akan menjaga kita,” '
#             'jelasnya.\n'
#             'Pada kesempatan itu, wali kota juga berpesan kepada generasi muda '
#             'untuk berperan serta di dalam pembangunan.',
#  'Time': 'Mon, 18 Jul 2022 14:43:58 GMT',
#  'Title': 'Buka Dialog Bersama Pemuda Taman, Wali Kota Dorong Peningkatan '
#           'Kompetensi Generasi Muda | - madiuntoday',
#  'TotalKata': 77,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'terus',
#                 'dorong',
#                 'pemuda',
#                 'untuk',
#                 'tingkat',
#                 'kompetensi',
#                 'hal',
#                 'ini',
#                 'seperti',
#                 'yang',
#                 'ungkap',
#                 'oleh',
#                 'orang',
#                 'nomor',
#                 'satu',
#                 'di',
#                 'kota',
#                 'pendekar',
#                 'ini',
#                 'saat',
#                 'hadir',
#                 'temu',
#                 'dengan',
#                 'karang',
#                 'taruna',
#                 'kelompok',
#                 'pemuda',
#                 'influencer',
#                 'dan',
#                 'forum',
#                 'anak',
#                 'kota',
#                 'madiun',
#                 'di',
#                 'lurah',
#                 'taman',
#                 'senin',
#                 '18',
#                 '7',
#                 'anak',
#                 'muda',
#                 'harus',
#                 'peran',
#                 'dalam',
#                 'bangun',
#                 'tutur',
#                 'turut',
#                 'wali',
#                 'kota',
#                 'kota',
#                 'madiun',
#                 'tidak',
#                 'milik',
#                 'hasil',
#                 'alam',
#                 'yang',
#                 'dapat',
#                 'manfaat',
#                 'oleh',
#                 'generasi',
#                 'datang',
#                 'karena',
#                 'bekal',
#                 'yang',
#                 'dapat',
#                 'siap',
#                 'adalah',
#                 'ilmu',
#                 'yang',
#                 'manfaat',
#                 'untuk',
#                 'itu',
#                 'mantan',
#                 'sekda',
#                 'kota',
#                 'madin',
#                 'sebut',
#                 'terus',
#                 'pacu',
#                 'pemuda',
#                 'agar',
#                 'tak',
#                 'henti',
#                 'ajar',
#                 'salah',
#                 'satu',
#                 'dengan',
#                 'kuasa',
#                 'terampil',
#                 'tentu',
#                 'ilmu',
#                 'itu',
#                 'bekal',
#                 'kita',
#                 'di',
#                 'masa',
#                 'depan',
#                 'kalau',
#                 'kita',
#                 'banyak',
#                 'ilmu',
#                 'maka',
#                 'ilmu',
#                 'itu',
#                 'yang',
#                 'akan',
#                 'jaga',
#                 'kita',
#                 'jelas',
#                 'pada',
#                 'sempat',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'pesan',
#                 'kepada',
#                 'generasi',
#                 'muda',
#                 'untuk',
#                 'peran',
#                 'serta',
#                 'di',
#                 'dalam',
#                 'bangun',
#                 'yakni',
#                 'dengan',
#                 'beri',
#                 'usul',
#                 'yang',
#                 'bangun',
#                 'sila',
#                 'sampai',
#                 'langsung',
#                 'ke',
#                 'pemkot',
#                 'atau',
#                 'lewat',
#                 'dewan',
#                 'asal',
#                 'sampai',
#                 'dengan',
#                 'cara',
#                 'yang',
#                 'baik',
#                 'tandas',
#                 'nanda',
#                 'irs',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'dorong',
#                'pemuda',
#                'tingkat',
#                'kompetensi',
#                'orang',
#                'nomor',
#                'kota',
#                'pendekar',
#                'hadir',
#                'temu',
#                'karang',
#                'taruna',
#                'kelompok',
#                'pemuda',
#                'influencer',
#                'forum',
#                'anak',
#                'kota',
#                'madiun',
#                'lurah',
#                'taman',
#                'senin',
#                '18',
#                '7',
#                'anak',
#                'muda',
#                'peran',
#                'bangun',
#                'wali',
#                'kota',
#                'kota',
#                'madiun',
#                'milik',
#                'hasil',
#                'alam',
#                'manfaat',
#                'generasi',
#                'bekal',
#                'ilmu',
#                'manfaat',
#                'mantan',
#                'sekda',
#                'kota',
#                'madin',
#                'pacu',
#                'pemuda',
#                'henti',
#                'ajar',
#                'salah',
#                'kuasa',
#                'terampil',
#                'ilmu',
#                'bekal',
#                'ilmu',
#                'ilmu',
#                'jaga',
#                'wali',
#                'kota',
#                'pesan',
#                'generasi',
#                'muda',
#                'peran',
#                'bangun',
#                'usul',
#                'bangun',
#                'sila',
#                'langsung',
#                'pemkot',
#                'dewan',
#                'nanda',
#                'irs',
#                'diskominfo']}
# {'Article': 'MADIUN – Wali Kota Madiun Maidi terus mendorong pemuda untuk '
#             'meningkatkan kompetensi. Hal ini seperti yang diungkapkan oleh '
#             'orang nomor satu di Kota Pendekar ini saat menghadiri pertemuan '
#             'dengan Karang Taruna, Kelompok Pemuda, Influencer, dan Forum Anak '
#             'Kota Madiun di Kelurahan Taman, Senin (18/7).\n'
#             '\n'
#             '“Anak muda harus berperan dalam pembangunan,” tuturnya.\n'
#             '\n'
#             'Menurut wali kota, Kota Madiun tidak memiliki hasil alam yang '
#             'dapat dimanfaatkan oleh generasi mendatang. Karenanya, bekal yang '
#             'dapat disiapkan adalah ilmu yang bermanfaat.\n'
#             '\n'
#             'Untuk itu, Mantan Sekda Kota Madin tersebut terus memacu pemuda '
#             'agar tak henti belajar. Salah satunya, dengan menguasai '
#             'keterampilan tertentu.\n'
#             '\n'
#             '“Ilmu itu bekal kita di masa depan. Kalau kita banyak ilmu, maka '
#             'ilmu itu yang akan menjaga kita,” jelasnya.\n'
#             '\n'
#             'Pada kesempatan itu, wali kota juga berpesan kepada generasi muda '
#             'untuk berperan serta di dalam pembangunan. Yakni, dengan '
#             'memberikan usulan-usulan yang membangun.\n'
#             '\n'
#             '“Silakan disampaikan. Langsung ke pemkot atau lewat dewan. '
#             'Asalkan disampaikan dengan cara yang baik,” tandasnya. '
#             '(Nanda/irs/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/buka-dialog-bersama-pemuda-taman-wali-kota-dorong-peningkatan-kompetensi-generasi-muda/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi terus dorong pemuda untuk tingkat '
#              'kompetensi hal ini seperti yang ungkap oleh orang nomor satu di '
#              'kota pendekar ini saat hadir temu dengan karang taruna kelompok '
#              'pemuda influencer dan forum anak kota madiun di lurah taman '
#              'senin 18 7 anak muda harus peran dalam bangun tutur turut wali '
#              'kota kota madiun tidak milik hasil alam yang dapat manfaat oleh '
#              'generasi datang karena bekal yang dapat siap adalah ilmu yang '
#              'manfaat untuk itu mantan sekda kota madin sebut terus pacu '
#              'pemuda agar tak henti ajar salah satu dengan kuasa terampil '
#              'tentu ilmu itu bekal kita di masa depan kalau kita banyak ilmu '
#              'maka ilmu itu yang akan jaga kita jelas pada sempat itu wali '
#              'kota juga pesan kepada generasi muda untuk peran serta di dalam '
#              'bangun yakni dengan beri usul yang bangun sila sampai langsung '
#              'ke pemkot atau lewat dewan asal sampai dengan cara yang baik '
#              'tandas nanda irs diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun Maidi terus mendorong pemuda untuk '
#             'meningkatkan kompetensi.\n'
#             'Hal ini seperti yang diungkapkan oleh orang nomor satu di Kota '
#             'Pendekar ini saat menghadiri pertemuan dengan Karang Taruna, '
#             'Kelompok Pemuda, Influencer, dan Forum Anak Kota Madiun di '
#             'Kelurahan Taman, Senin (18/7).\n'
#             'Menurut wali kota, Kota Madiun tidak memiliki hasil alam yang '
#             'dapat dimanfaatkan oleh generasi mendatang.\n'
#             'Kalau kita banyak ilmu, maka ilmu itu yang akan menjaga kita,” '
#             'jelasnya.\n'
#             'Pada kesempatan itu, wali kota juga berpesan kepada generasi muda '
#             'untuk berperan serta di dalam pembangunan.',
#  'Time': 'Mon, 18 Jul 2022 14:43:58 GMT',
#  'Title': 'Buka Dialog Bersama Pemuda Taman, Wali Kota Dorong Peningkatan '
#           'Kompetensi Generasi Muda | - madiuntoday',
#  'TotalKata': 77,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'terus',
#                 'dorong',
#                 'pemuda',
#                 'untuk',
#                 'tingkat',
#                 'kompetensi',
#                 'hal',
#                 'ini',
#                 'seperti',
#                 'yang',
#                 'ungkap',
#                 'oleh',
#                 'orang',
#                 'nomor',
#                 'satu',
#                 'di',
#                 'kota',
#                 'pendekar',
#                 'ini',
#                 'saat',
#                 'hadir',
#                 'temu',
#                 'dengan',
#                 'karang',
#                 'taruna',
#                 'kelompok',
#                 'pemuda',
#                 'influencer',
#                 'dan',
#                 'forum',
#                 'anak',
#                 'kota',
#                 'madiun',
#                 'di',
#                 'lurah',
#                 'taman',
#                 'senin',
#                 '18',
#                 '7',
#                 'anak',
#                 'muda',
#                 'harus',
#                 'peran',
#                 'dalam',
#                 'bangun',
#                 'tutur',
#                 'turut',
#                 'wali',
#                 'kota',
#                 'kota',
#                 'madiun',
#                 'tidak',
#                 'milik',
#                 'hasil',
#                 'alam',
#                 'yang',
#                 'dapat',
#                 'manfaat',
#                 'oleh',
#                 'generasi',
#                 'datang',
#                 'karena',
#                 'bekal',
#                 'yang',
#                 'dapat',
#                 'siap',
#                 'adalah',
#                 'ilmu',
#                 'yang',
#                 'manfaat',
#                 'untuk',
#                 'itu',
#                 'mantan',
#                 'sekda',
#                 'kota',
#                 'madin',
#                 'sebut',
#                 'terus',
#                 'pacu',
#                 'pemuda',
#                 'agar',
#                 'tak',
#                 'henti',
#                 'ajar',
#                 'salah',
#                 'satu',
#                 'dengan',
#                 'kuasa',
#                 'terampil',
#                 'tentu',
#                 'ilmu',
#                 'itu',
#                 'bekal',
#                 'kita',
#                 'di',
#                 'masa',
#                 'depan',
#                 'kalau',
#                 'kita',
#                 'banyak',
#                 'ilmu',
#                 'maka',
#                 'ilmu',
#                 'itu',
#                 'yang',
#                 'akan',
#                 'jaga',
#                 'kita',
#                 'jelas',
#                 'pada',
#                 'sempat',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'pesan',
#                 'kepada',
#                 'generasi',
#                 'muda',
#                 'untuk',
#                 'peran',
#                 'serta',
#                 'di',
#                 'dalam',
#                 'bangun',
#                 'yakni',
#                 'dengan',
#                 'beri',
#                 'usul',
#                 'yang',
#                 'bangun',
#                 'sila',
#                 'sampai',
#                 'langsung',
#                 'ke',
#                 'pemkot',
#                 'atau',
#                 'lewat',
#                 'dewan',
#                 'asal',
#                 'sampai',
#                 'dengan',
#                 'cara',
#                 'yang',
#                 'baik',
#                 'tandas',
#                 'nanda',
#                 'irs',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'dorong',
#                'pemuda',
#                'tingkat',
#                'kompetensi',
#                'orang',
#                'nomor',
#                'kota',
#                'pendekar',
#                'hadir',
#                'temu',
#                'karang',
#                'taruna',
#                'kelompok',
#                'pemuda',
#                'influencer',
#                'forum',
#                'anak',
#                'kota',
#                'madiun',
#                'lurah',
#                'taman',
#                'senin',
#                '18',
#                '7',
#                'anak',
#                'muda',
#                'peran',
#                'bangun',
#                'wali',
#                'kota',
#                'kota',
#                'madiun',
#                'milik',
#                'hasil',
#                'alam',
#                'manfaat',
#                'generasi',
#                'bekal',
#                'ilmu',
#                'manfaat',
#                'mantan',
#                'sekda',
#                'kota',
#                'madin',
#                'pacu',
#                'pemuda',
#                'henti',
#                'ajar',
#                'salah',
#                'kuasa',
#                'terampil',
#                'ilmu',
#                'bekal',
#                'ilmu',
#                'ilmu',
#                'jaga',
#                'wali',
#                'kota',
#                'pesan',
#                'generasi',
#                'muda',
#                'peran',
#                'bangun',
#                'usul',
#                'bangun',
#                'sila',
#                'langsung',
#                'pemkot',
#                'dewan',
#                'nanda',
#                'irs',
#                'diskominfo']}
# {'Article': 'MADIUN – Penanganan stunting merupakan tanggung jawab bersama. '
#             'Tak terkecuali dari tenaga pendidik. Kali ini, perhatian datang '
#             'dari 132 guru PPPK angkatan 2021. Mereka menghimpun dana untuk '
#             'kemudian diwujudkan sembako dan asupan gizi kepada keluarga '
#             'stunting. Setidaknya, ada 50 paket sembako yang dibagikan kepada '
#             'bayi stunting tersebut. Sepuluh di antaranya dibagikan langsung '
#             'Wali Kota Madiun, Maidi di Rumah Dinas Wali Kota, Senin (18/7).\n'
#             '\n'
#             '‘’Stunting kita sudah dibawah target nasional. Tetapi jangan puas '
#             'dulu. Harus terus diupayakan untuk ditekan. Terima kasih kepada '
#             'guru PPPK yang juga turut menekan angka stunting ini,’’ kata wali '
#             'kota.\n'
#             '\n'
#             'Guru, kata wali kota, memang harus kreatif. Tidak hanya harus '
#             'mampu menstranfer ilmunya kepada peserta didik. Tetapi juga harus '
#             'bisa memahami kebutuhan peserta didik termasuk urusan '
#             'kesehatannya. Sebab, murid yang kurang sehat juga akan '
#             'mempengaruhi proses belajar mengajarnya. Stunting, lanjut wali '
#             'kota, pasti akan berpengaruh pada proses KBM tersebut. Karenanya, '
#             'pemerintah terus berupaya menekan angka stunting.\n'
#             '\n'
#             '‘’Guru PAUD yang bisa tekan stunting diberi reward. Kita '
#             'sekolahkan lagi. Kita beri pelatihan-pelatihan,’’ jelas wali '
#             'kota.\n'
#             '\n'
#             'Program tersebut sebagai wujud syukur ratusan PPPK rekrutmen 2021 '
#             'tersebut. Mereka kini telah bertugas di sejumlah sekolah di Kota '
#             'Madiun. Wali kota berharap kepedulian terus ditingkatkan. '
#             'Harapannya, angka stunting di Kota Madiun terus turun. Saat ini, '
#             'stunting Kota Madiun di angka 12 persen. Sedang, target '
#             'pemerintah pusat di bawah 14 persen pada 2024 nanti. Artinya, '
#             'Kota Madiun sudah di bawah target pusat kendati target tersebut '
#             'masih akan diterapkan.\n'
#             '\n'
#             '‘’Ini awal yang baik. Apapun itu kalau didasari kerja keras, '
#             'kerja cerdas, dan kerja ikhlas, hasilnya akan baik,’’ pungkasnya. '
#             '(nanda/agi/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/silaturahmi-dengan-guru-pppk-wali-kota-apresiasi-guru-pppk-turut-tangani-stunting/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun tangan stunting rupa tanggung jawab sama tak kecuali dari '
#              'tenaga didik kali ini perhati datang dari 132 guru pppk angkat '
#              '2021 mereka himpun dana untuk kemudian wujud sembako dan asupan '
#              'gizi kepada keluarga stunting tidak ada 50 paket sembako yang '
#              'bagi kepada bayi stunting sebut puluh di antara bagi langsung '
#              'wali kota madiun maidi di rumah dinas wali kota senin 18 7 '
#              'stunting kita sudah bawah target nasional tetapi jangan puas '
#              'dulu harus terus upaya untuk tekan terima kasih kepada guru pppk '
#              'yang juga turut tekan angka stunting ini kata wali kota guru '
#              'kata wali kota memang harus kreatif tidak hanya harus mampu '
#              'menstranfer ilmu kepada serta didik tetapi juga harus bisa paham '
#              'butuh serta didik masuk urus sehat sebab murid yang kurang sehat '
#              'juga akan pengaruh proses ajar ajar stunting lanjut wali kota '
#              'pasti akan pengaruh pada proses kbm sebut karena perintah terus '
#              'upaya tekan angka stunting guru paud yang bisa tekan stunting '
#              'beri reward kita sekolah lagi kita beri latih jelas wali kota '
#              'program sebut bagai wujud syukur ratus pppk rekrutmen 2021 sebut '
#              'mereka kini telah tugas di jumlah sekolah di kota madiun wali '
#              'kota harap peduli terus tingkat harap angka stunting di kota '
#              'madiun terus turun saat ini stunting kota madiun di angka 12 '
#              'persen sedang target perintah pusat di bawah 14 persen pada 2024 '
#              'nanti arti kota madiun sudah di bawah target pusat kendati '
#              'target sebut masih akan terap ini awal yang baik apa itu kalau '
#              'dasar kerja keras kerja cerdas dan kerja ikhlas hasil akan baik '
#              'pungkas nanda agi diskominfo',
#  'Summary': 'Sepuluh di antaranya dibagikan langsung Wali Kota Madiun, Maidi '
#             'di Rumah Dinas Wali Kota, Senin (18/7).\n'
#             'Terima kasih kepada guru PPPK yang juga turut menekan angka '
#             'stunting ini,’’ kata wali kota.\n'
#             'Mereka kini telah bertugas di sejumlah sekolah di Kota Madiun.\n'
#             'Harapannya, angka stunting di Kota Madiun terus turun.\n'
#             'Saat ini, stunting Kota Madiun di angka 12 persen.',
#  'Time': 'Mon, 18 Jul 2022 14:39:50 GMT',
#  'Title': 'Silaturahmi dengan Guru PPPK, Wali Kota Apresiasi Guru PPPK Turut '
#           'Tangani Stunting | - madiuntoday',
#  'TotalKata': 149,
#  'WordTokens': ['madiun',
#                 'tangan',
#                 'stunting',
#                 'rupa',
#                 'tanggung',
#                 'jawab',
#                 'sama',
#                 'tak',
#                 'kecuali',
#                 'dari',
#                 'tenaga',
#                 'didik',
#                 'kali',
#                 'ini',
#                 'perhati',
#                 'datang',
#                 'dari',
#                 '132',
#                 'guru',
#                 'pppk',
#                 'angkat',
#                 '2021',
#                 'mereka',
#                 'himpun',
#                 'dana',
#                 'untuk',
#                 'kemudian',
#                 'wujud',
#                 'sembako',
#                 'dan',
#                 'asupan',
#                 'gizi',
#                 'kepada',
#                 'keluarga',
# ...
#                'drs',
#                'h',
#                'maidi',
#                'sh',
#                'mm',
#                'm',
#                'pd',
#                'walikota',
#                'madiun',
#                'yuni',
#                'setyowati',
#                'maidi',
#                '2',
#                'jajar',
#                'pimpin',
#                'kepala',
#                'opd',
#                'kota',
#                'madiun',
#                '3',
#                'bpk',
#                'danang',
#                'mardianto',
#                's',
#                's',
#                't',
#                'p',
#                'm',
#                'h',
#                'camat',
#                'manguharjo',
#                'camat',
#                'kec',
#                'manguharjo',
#                '4',
#                'rahma',
#                'indah',
#                'heriastuti',
#                'sp',
#                'ka',
#                'kel',
#                'nambangan',
#                'kidul',
#                '5',
#                'babinsa',
#                'babinkamtibmas',
#                'kel',
#                'nambangan',
#                'kidul',
#                '6',
#                'dinas',
#                'daya',
#                'lebah',
#                'madu',
#                '2',
#                'org',
#                'narasumber',
#                'tenaga',
#                'ahli',
#                'komunitas',
#                'ternak',
#                'lebah',
#                'madu',
#                'kota',
#                'madiun',
#                '7',
#                'ketua',
#                'lpmk',
#                'nambangan',
#                'kidul',
#                '8',
#                'staf',
#                'kec',
#                'manguharjo',
#                '9',
#                'staf',
#                'kel',
#                'nambangan',
#                'kidul',
#                '10',
#                'latih',
#                'pembudidayaan',
#                'lebah',
#                'madu',
#                'latih',
#                'ternak',
#                'lebah',
#                'madu',
#                'lurah',
#                'nambang',
#                'kidul',
#                'madiun',
#                'sambut',
#                'wali',
#                'kota',
#                'nyata',
#                'kota',
#                'pabrik',
#                'madu',
#                'antusias',
#                'masyarakat',
#                'semangat',
#                'latih',
#                'wali',
#                'kota',
#                'lebah',
#                'cari',
#                'makan',
#                'lebah',
#                'nyaman',
#                'mudah',
#                'cari',
#                'makan',
#                'ilmu',
#                'maksimal',
#                'ahli',
#                'wali',
#                'kota',
#                'hadir',
#                'latih',
#                'budidaya',
#                'lebah',
#                'wali',
#                'kota',
#                'sembako',
#                'warga',
#                'masyarakat',
#                'nambangan',
#                'kidul',
#                'madu',
#                'hasil',
#                'kualitas',
#                'lingkung',
#                'budidaya',
#                'dukung',
#                'gantung',
#                'milik',
#                'madu',
#                'hasil',
#                'ternak',
#                'latih',
#                'lomba',
#                'wali',
#                'kota',
#                'dorong',
#                'masyarakat',
#                'kembang',
#                'budidaya',
#                'lebah',
#                'pacu',
#                'masyarakat',
#                'gelar',
#                'lomba',
#                'lomba',
#                'menang',
#                'lebah',
#                'latih',
#                'lebah',
#                'bukti',
#                'hasil',
#                'pungkas',
#                'adv',
#                'john',
#                'mz',
#                'reporter',
#                'jhon',
#                'mongaz',
#                'editor',
#                'publisher',
#                'a',
#                'estika']}
# {'Article': 'MADIUN – Wali Kota Madiun Maidi kembali menggelar giat gowes '
#             'pagi. Sama seperti sebelumnya, gowes dilakukan sembari meninjau '
#             'lapak-lapak UMKM. Kali ini orang nomor satu di Kota Madiun itu '
#             'meninjau dua lapak UMKM yang ada di Kecamatan Kartoharjo, yakni '
#             'Lapak Pilangbango dan Rejomulyo.\n'
#             '\n'
#             'Kesempatan tersebut sekaligus dijadikan sebagai ajang bertukar '
#             'informasi dan sarana menyampaikan usulan. Seperti yang dilakukan '
#             'para pelaku seni jaranan yang ada di Kelurahan Pilangbango.\n'
#             '\n'
#             'Wali kota menyambut baik berbagai usulan yang diterima. Orang '
#             'nomor satu di Kota Madiun itu mengatakan agar apa yang dibutuhkan '
#             'segera ditulis untuk kemudian dipenuhi.\n'
#             '\n'
#             '“Apa yang menjadi kebutuhan pelaku seni silahkan ditulis. Nanti '
#             'akan kita penuhi,” ungkapnya, Senin (18/7).\n'
#             '\n'
#             'Lebih lanjut wali kota mengatakan, Kota Madiun kini sudah maju. '
#             'Maka dari itu dirinya mengatakan agar seluruh warga mampu menjadi '
#             'pemain dalam ikut serta membangun kota. Salah satu caranya yakni '
#             'dengan menjaga kerukunan dan keamanan yang ada di wilayah '
#             'tersebut.\n'
#             '\n'
#             '“Kota ini maju tapi kalian jangan jadi penonton tapi jadilah '
#             'pemain juga. Saya minta jaga kedamaian dan kerukunan. Ada '
#             'gangguan selesaikan dengan baik,” terangnya.\n'
#             '\n'
#             'Tak hanya itu, wali kota juga mengimbau agar jangan mudah '
#             'tersulut dengan isu-isu yang belum pasti kebenarannya. Seluruh '
#             'usulan dan masukan akan diwadahi asalkan sesuai dengan kebutuhan '
#             'masyarakat.\n'
#             '\n'
#             '(WS Hendro/kus/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/18/gowes-pagi-pak-wali-serap-aspirasi-para-pelaku-seni/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi kembali gelar giat gowes pagi sama '
#              'seperti belum gowes laku sembari tinjau lapak umkm kali ini '
#              'orang nomor satu di kota madiun itu tinjau dua lapak umkm yang '
#              'ada di camat kartoharjo yakni lapak pilangbango dan rejomulyo '
#              'sempat sebut sekaligus jadi bagai ajang tukar informasi dan '
#              'sarana sampai usul seperti yang laku para laku seni jaranan yang '
#              'ada di lurah pilangbango wali kota sambut baik bagai usul yang '
#              'terima orang nomor satu di kota madiun itu kata agar apa yang '
#              'butuh segera tulis untuk kemudian penuh apa yang jadi butuh laku '
#              'seni silah tulis nanti akan kita penuh ungkap senin 18 7 lebih '
#              'lanjut wali kota kata kota madiun kini sudah maju maka dari itu '
#              'diri kata agar seluruh warga mampu jadi main dalam ikut serta '
#              'bangun kota salah satu cara yakni dengan jaga rukun dan aman '
#              'yang ada di wilayah sebut kota ini maju tapi kalian jangan jadi '
#              'tonton tapi jadi main juga saya minta jaga damai dan rukun ada '
#              'ganggu selesai dengan baik terang tak hanya itu wali kota juga '
#              'imbau agar jangan mudah sulut dengan isu yang belum pasti benar '
#              'seluruh usul dan masuk akan wadah asal sesuai dengan butuh '
#              'masyarakat ws hendro kus diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun Maidi kembali menggelar giat gowes '
#             'pagi.\n'
#             'Kali ini orang nomor satu di Kota Madiun itu meninjau dua lapak '
#             'UMKM yang ada di Kecamatan Kartoharjo, yakni Lapak Pilangbango '
#             'dan Rejomulyo.\n'
#             'Seperti yang dilakukan para pelaku seni jaranan yang ada di '
#             'Kelurahan Pilangbango.\n'
#             'Orang nomor satu di Kota Madiun itu mengatakan agar apa yang '
#             'dibutuhkan segera ditulis untuk kemudian dipenuhi.\n'
#             'Lebih lanjut wali kota mengatakan, Kota Madiun kini sudah maju.',
#  'Time': 'Mon, 18 Jul 2022 08:21:11 GMT',
#  'Title': 'Gowes Pagi Pak Wali Serap Aspirasi Para Pelaku Seni | - madiuntoday',
#  'TotalKata': 100,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'kembali',
#                 'gelar',
#                 'giat',
#                 'gowes',
#                 'pagi',
#                 'sama',
#                 'seperti',
#                 'belum',
#                 'gowes',
#                 'laku',
#                 'sembari',
#                 'tinjau',
#                 'lapak',
#                 'umkm',
#                 'kali',
#                 'ini',
#                 'orang',
#                 'nomor',
#                 'satu',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'itu',
#                 'tinjau',
#                 'dua',
#                 'lapak',
#                 'umkm',
#                 'yang',
#                 'ada',
#                 'di',
#                 'camat',
#                 'kartoharjo',
#                 'yakni',
#                 'lapak',
#                 'pilangbango',
#                 'dan',
#                 'rejomulyo',
#                 'sempat',
#                 'sebut',
#                 'sekaligus',
#                 'jadi',
#                 'bagai',
#                 'ajang',
#                 'tukar',
#                 'informasi',
#                 'dan',
#                 'sarana',
#                 'sampai',
#                 'usul',
#                 'seperti',
#                 'yang',
#                 'laku',
#                 'para',
#                 'laku',
#                 'seni',
#                 'jaranan',
#                 'yang',
#                 'ada',
#                 'di',
#                 'lurah',
#                 'pilangbango',
#                 'wali',
#                 'kota',
#                 'sambut',
#                 'baik',
#                 'bagai',
#                 'usul',
#                 'yang',
#                 'terima',
#                 'orang',
#                 'nomor',
#                 'satu',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'itu',
#                 'kata',
#                 'agar',
#                 'apa',
#                 'yang',
#                 'butuh',
#                 'segera',
#                 'tulis',
#                 'untuk',
#                 'kemudian',
#                 'penuh',
#                 'apa',
#                 'yang',
#                 'jadi',
#                 'butuh',
#                 'laku',
#                 'seni',
#                 'silah',
#                 'tulis',
#                 'nanti',
#                 'akan',
#                 'kita',
#                 'penuh',
#                 'ungkap',
#                 'senin',
#                 '18',
#                 '7',
#                 'lebih',
#                 'lanjut',
#                 'wali',
#                 'kota',
#                 'kata',
#                 'kota',
#                 'madiun',
#                 'kini',
#                 'sudah',
#                 'maju',
#                 'maka',
#                 'dari',
#                 'itu',
#                 'diri',
#                 'kata',
#                 'agar',
#                 'seluruh',
#                 'warga',
#                 'mampu',
#                 'jadi',
#                 'main',
#                 'dalam',
#                 'ikut',
#                 'serta',
#                 'bangun',
#                 'kota',
#                 'salah',
#                 'satu',
#                 'cara',
#                 'yakni',
#                 'dengan',
#                 'jaga',
#                 'rukun',
#                 'dan',
#                 'aman',
#                 'yang',
#                 'ada',
#                 'di',
#                 'wilayah',
#                 'sebut',
#                 'kota',
#                 'ini',
#                 'maju',
#                 'tapi',
#                 'kalian',
#                 'jangan',
#                 'jadi',
#                 'tonton',
#                 'tapi',
#                 'jadi',
#                 'main',
#                 'juga',
#                 'saya',
#                 'minta',
#                 'jaga',
#                 'damai',
#                 'dan',
#                 'rukun',
#                 'ada',
#                 'ganggu',
#                 'selesai',
#                 'dengan',
#                 'baik',
#                 'terang',
#                 'tak',
#                 'hanya',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'imbau',
#                 'agar',
#                 'jangan',
#                 'mudah',
#                 'sulut',
#                 'dengan',
#                 'isu',
#                 'yang',
#                 'belum',
#                 'pasti',
#                 'benar',
#                 'seluruh',
#                 'usul',
#                 'dan',
#                 'masuk',
#                 'akan',
#                 'wadah',
#                 'asal',
#                 'sesuai',
#                 'dengan',
#                 'butuh',
#                 'masyarakat',
#                 'ws',
#                 'hendro',
#                 'kus',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'gelar',
#                'giat',
#                'gowes',
#                'pagi',
#                'gowes',
#                'laku',
#                'sembari',
#                'tinjau',
#                'lapak',
#                'umkm',
#                'kali',
#                'orang',
#                'nomor',
#                'kota',
#                'madiun',
#                'tinjau',
#                'lapak',
#                'umkm',
#                'camat',
#                'kartoharjo',
#                'lapak',
#                'pilangbango',
#                'rejomulyo',
#                'ajang',
#                'tukar',
#                'informasi',
#                'sarana',
#                'usul',
#                'laku',
#                'laku',
#                'seni',
#                'jaranan',
#                'lurah',
#                'pilangbango',
#                'wali',
#                'kota',
#                'sambut',
#                'usul',
#                'terima',
#                'orang',
#                'nomor',
#                'kota',
#                'madiun',
#                'butuh',
#                'tulis',
#                'penuh',
#                'butuh',
#                'laku',
#                'seni',
#                'silah',
#                'tulis',
#                'penuh',
#                'senin',
#                '18',
#                '7',
#                'wali',
#                'kota',
#                'kota',
#                'madiun',
#                'maju',
#                'warga',
#                'main',
#                'bangun',
#                'kota',
#                'salah',
#                'jaga',
#                'rukun',
#                'aman',
#                'wilayah',
#                'kota',
#                'maju',
#                'tonton',
#                'main',
#                'jaga',
#                'damai',
#                'rukun',
#                'ganggu',
#                'selesai',
#                'terang',
#                'wali',
#                'kota',
#                'imbau',
#                'mudah',
#                'sulut',
#                'isu',
#                'usul',
#                'masuk',
#                'wadah',
#                'sesuai',
#                'butuh',
#                'masyarakat',
#                'ws',
#                'hendro',
#                'kus',
#                'diskominfo']}
# Download news_today.txt Sucessfully
# Download news_today.csv Sucessfully
# Now Enter Your Topics to Search or Exit: Exit
# See you, hope you have a great day! ❤️

# %%
# Python program to generate WordCloud
 
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv((input('Masukkan file: ')), encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.WordsStop:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
# Out:
# Masukkan file: maidi.csv
