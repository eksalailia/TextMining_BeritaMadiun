# %% [markdown]
# <a href="https://colab.research.google.com/github/ardilalukita14/Magang-Kominfo/blob/main/Project_Magang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Install Library yang Dibutuhkan**

# %%
# !pip install GoogleNews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: GoogleNews in /usr/local/lib/python3.7/dist-packages (1.6.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from GoogleNews) (4.11.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.7/dist-packages (from GoogleNews) (0.7.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4->GoogleNews) (2.3.2.post1)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.7/dist-packages (from dateparser->GoogleNews) (2022.3.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser->GoogleNews) (2022.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser->GoogleNews) (1.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->GoogleNews) (1.15.0)

# %%
# !pip install pygooglenews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pygooglenews in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: feedparser<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pygooglenews) (5.2.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.7/dist-packages (from pygooglenews) (4.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from pygooglenews) (2.28.1)
# Requirement already satisfied: dateparser<0.8.0,>=0.7.6 in /usr/local/lib/python3.7/dist-packages (from pygooglenews) (0.7.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->pygooglenews) (2.3.2.post1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.3.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
# !pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.7/dist-packages (0.2.8)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (7.1.2)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.3.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.2.6)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.13)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.7)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (5.2.1)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.28.1)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.2.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.3.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->newspaper3k) (4.64.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.7.1)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)

# %% [markdown]
# ## **Proses Scraping, Stemming, Stop Words Google News**

# %%
# import library 
from pygooglenews import GoogleNews
import csv
from newspaper import Article
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('punkt')
from pprint import pprint
from textblob import TextBlob
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import datetime
import pandas as pd
from time import sleep
#from google.colab import files
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
f = open("stop words.txt", "r")
stopword_list = []
for line in f:
    stripped_line = line.strip()
    line_list = stripped_line.split()
    stopword_list.append(line_list[0])
f.close()

len(stopword_list)
# Out:
# 758

# %%
# Scrapping Function to get google news (title, link)
gn = GoogleNews(lang = 'id',country = 'ID') 
def get_titles(search):
    stories = []

    # setting tanggal
    start_date = datetime.date(2022,7,1)
    end_date = datetime.date(2022,7,16)
    delta = datetime.timedelta(days=1)
    date_list = pd.date_range(start_date, end_date).tolist()
    
    for date in date_list[:-1]:
        result = gn.search(search, from_=date.strftime('%Y-%m-%d'), to_=(date+delta).strftime('%Y-%m-%d'), when = '1d')
        newsitem = result['entries']
   # stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    for item in newsitem:
        url=item.link
        try:
            article = Article(url)
            article.download()
            article.parse()
            story = {
                'Title' : item.title,
                'Read more' : item.link,
                'Time' : item.published,
                'Article' : article.text,
                'Stemming' : stemmer.stem(article.text),
                'WordTokens' :(word_tokenize(stemmer.stem(article.text))),
                'WordsStop' : [w for w in (word_tokenize(stemmer.stem(article.text))) if not w in stopword_list ],
                'TotalKata' : len([w for w in (word_tokenize(stemmer.stem(article.text))) if not w in stopword_list ])
                }
            if article.title=="Are you a robot?" or article.title=="Subscribe to read" :
                continue
            else:
                stories.append(story)
                i=i+1
                print(i,'',article.title)
                sleep(1)
        except:
              pass
        stories.append(story)
        sleep(0)
    return stories

# %%
# Process Summarize Goolge News Article + Sentiment Analysis of Google News
def summarize_artcle(url):
    article = Article(url)
    # Set up 
    article.download()
    article.parse()
    # Download Punkt
    article.download('punkt')
    article.nlp()
    summary = article.summary

    analysis = TextBlob(article.text)
    sentiment_a =""
    if analysis.polarity > 0:
      sentiment_a="positif"
    elif analysis.polarity < 0:
      sentiment_a="negatif"
    else:
       sentiment_a="netral"

    return summary,sentiment_a

# %%
#Function to save a list
def save_dict(topic, number):
    try: 
      dcts = get_titles(topic)
      news_list = []
      for x in range(number):
        dctss = dcts[x]
        url = dctss['Read more']
        try:
          summary_analysis = list(summarize_artcle(url))
          dctss['Sentiment'] = summary_analysis[1]
          dctss['Summary'] = summary_analysis[0]
        except:
          dctss['Sentiment'] = 'error'
          dctss['Summary'] ='error'
        news_list.append(dctss)
        pprint(dctss)
      return news_list 
    except:
        print('Please input useable topics, thanks or check this -> https://github.com/kotartemiy/pygooglenews#installation')

# %%
#Function to Save a CSV file
def save_to_csv(news_list):
    labels = ['Time', 'Title', 'Read more','Sentiment','Summary', 'Article', 'Stemming', 'WordTokens', 'WordsStop', 'TotalKata']
    try:
        with open(file, 'w') as f:
            writer = csv.DictWriter(f, fieldnames=labels)
            writer.writeheader()
            for elem in news_list:
                writer.writerow(elem)
        print("Download news_today.csv Sucessfully")
    except IOError:
        print("I/O error")
file = input('Rename file: ')
# Out:
# Rename file: madiun.csv

# %%
# Function to save a txt file

def save_to_txt(news_list):
    n=1
    with open(file_txt, 'w') as f: 
      for item in news_list: 
        f.write('-'*20+str(n)+'-'*20+'\n')
        n+=1
        for key, value in item.items(): 
          f.write('%s:\n %s\n' % (key, value))
    print("Download news_today.txt Sucessfully")
file_txt = input('Rename file: ')
# Out:
# Rename file: madiun.txt

# %%
# Let's run this    
print("Hi, there!")
topic = input('Now Enter your topics to Search or Exit: ')
while topic != 'Exit':
  number = int(input('How many articles you want to search (up to 100)? '))
  news_data = save_dict(topic, number)
  try:
    save_to_txt(news_data)
    save_to_csv(news_data)
  except:
    print("Retry it again!")
  topic = input('Now Enter Your Topics to Search or Exit: ')
print('See you, hope you have a great day! ❤️')
# Out:
# Streaming output truncated to the last 5000 lines.
#                 'juga',
#                 'rupa',
#                 'ajang',
#                 'gabung',
#                 'antara',
#                 'giat',
#                 'olahraga',
#                 'balap',
#                 'sepeda',
#                 'dan',
#                 'wisata',
#                 'sport',
#                 'tourism',
#                 'yang',
#                 'harap',
#                 'bisa',
#                 'bawa',
#                 'dampak',
#                 'pada',
#                 'giat',
#                 'promosi',
#                 'wisata',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'dan',
#                 'daerah',
#                 'sekitar',
#                 'yang',
#                 'lewat',
#                 'rute',
#                 'ketua',
#                 'ikat',
#                 'sport',
#                 'sepeda',
#                 'indonesia',
#                 'issi',
#                 'kota',
#                 'madiun',
#                 'faizal',
#                 'rachman',
#                 'kata',
#                 'mlc',
#                 '2022',
#                 'adalah',
#                 'buah',
#                 'terobos',
#                 'yang',
#                 'gagas',
#                 'bumn',
#                 'issi',
#                 'kota',
#                 'madiun',
#                 'dan',
#                 'pemkot',
#                 'madiun',
#                 'mlc',
#                 '2022',
#                 'adalahsepeda',
#                 'dengan',
#                 'kemas',
#                 'sport',
#                 'tourism',
#                 'yakni',
#                 'olahraga',
#                 'dengan',
#                 'misi',
#                 'prestasi',
#                 'dan',
#                 'wisata',
#                 'event',
#                 'yang',
#                 'proyeksi',
#                 'menjaditersebut',
#                 'rupa',
#                 'bentuk',
#                 'dukung',
#                 'hadap',
#                 'program',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'yang',
#                 'telah',
#                 'buat',
#                 'ubah',
#                 'besar',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'untuk',
#                 'dongkrak',
#                 'sektor',
#                 'pariwisata',
#                 'event',
#                 'itu',
#                 'juga',
#                 'rupa',
#                 'bagi',
#                 'dari',
#                 'rangkai',
#                 'ingat',
#                 'hari',
#                 'jadi',
#                 'kota',
#                 'madiun',
#                 'ke-104',
#                 'kami',
#                 'ajak',
#                 'serta',
#                 'dari',
#                 'bagai',
#                 'kota',
#                 'di',
#                 'indonesia',
#                 'dan',
#                 'mancanegara',
#                 'untuk',
#                 'partisipasi',
#                 'takluk',
#                 'tantang',
#                 'rute',
#                 'madiun-cemoro',
#                 'sewu',
#                 'dengan',
#                 'pandang',
#                 'eksotis',
#                 'sekaligus',
#                 'nikmat',
#                 'indah',
#                 'kota',
#                 'madiun',
#                 'dan',
#                 'sekitar',
#                 'kata',
#                 'adapun',
#                 'rangkai',
#                 'event',
#                 'mlc',
#                 '2022',
#                 'gelar',
#                 'lama',
#                 '3',
#                 'hari',
#                 'tanggal',
#                 '15-17',
#                 'juli',
#                 'pusat',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'hari',
#                 'pertama',
#                 'buka',
#                 'dengan',
#                 'fun',
#                 'bike',
#                 'atau',
#                 'sepeda',
#                 'santai',
#                 'sama',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'dengan',
#                 'rute',
#                 'sepeda',
#                 'wisata',
#                 'pada',
#                 'jumat',
#                 '15',
#                 '7',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'lanjut',
#                 'dengan',
#                 'pesta',
#                 'buka',
#                 'di',
#                 'kawasan',
#                 'taman',
#                 'sumber',
#                 'wangi',
#                 'pahlawan',
#                 'street',
#                 'center',
#                 'psc',
#                 'di',
#                 'hari',
#                 'pertama',
#                 'ratus',
#                 'cyclist',
#                 'ajak',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'dan',
#                 'forkopimda',
#                 'untuk',
#                 'nikmat',
#                 'indah',
#                 'tata',
#                 'kota',
#                 'madiun',
#                 'yang',
#                 'ramah',
#                 'sepeda',
#                 'lalu',
#                 'jalur',
#                 'sepeda',
#                 'wisata',
#                 'yang',
#                 'telah',
#                 'siap',
#                 'tak',
#                 'ada',
#                 'batas',
#                 'semua',
#                 'warga',
#                 'dengan',
#                 'tipe',
#                 'sepeda',
#                 'apa',
#                 'boleh',
#                 'ikut',
#                 'hari',
#                 'dua',
#                 'serta',
#                 'balap',
#                 'sepeda',
#                 'yang',
#                 'telah',
#                 'daftar',
#                 'ajak',
#                 'takluk',
#                 'jalur',
#                 'eksotis',
#                 'panjang',
#                 '70',
#                 'kilometer',
#                 'dengan',
#                 'elevasi',
#                 '1',
#                 '800',
#                 'meter',
#                 'rute',
#                 'madiun-cemoro',
#                 'sewu',
#                 'start',
#                 'dari',
#                 'balai',
#                 'kota',
#                 'madiun',
#                 'dan',
#                 'finish',
#                 'di',
#                 'coro',
#                 'sewu',
#                 'magetan',
#                 'bagi',
#                 'serta',
#                 'yang',
#                 'ingin',
#                 'adu',
#                 'cepat',
#                 'ada',
#                 'sesi',
#                 'criterium',
#                 'di',
#                 'hari',
#                 'tiga',
#                 'minggu',
#                 '17',
#                 '7',
#                 'bagai',
#                 'kelas',
#                 'akan',
#                 'tanding',
#                 'dari',
#                 'usia',
#                 'dini',
#                 'ajar',
#                 'atlet',
#                 'hobbies',
#                 'hingga',
#                 'mantan',
#                 'atlet',
#                 'ajang',
#                 'mlc',
#                 '2022',
#                 'hari',
#                 'dua',
#                 'dengan',
#                 'rute',
#                 'madiun-cemoro',
#                 'sewu',
#                 'magetan',
#                 'ikut',
#                 'oleh',
#                 'banyak',
#                 '320',
#                 'serta',
#                 'dari',
#                 'bagai',
#                 'daerah',
#                 'di',
#                 'tanah',
#                 'air',
#                 'tiga',
#                 'serta',
#                 'di',
#                 'antara',
#                 'asal',
#                 'dari',
#                 'mancanegara',
#                 'yakni',
#                 'inggris',
#                 'italia',
#                 'dan',
#                 'swiss',
#                 'dapat',
#                 'sembilan',
#                 'kategori',
#                 'di',
#                 'ajang',
#                 'mlc',
#                 '2022',
#                 'hari',
#                 'dua',
#                 'dengan',
#                 'rute',
#                 'madiun-cemoro',
#                 'sewu',
#                 'magetan',
#                 'yakni',
#                 'enam',
#                 'kategori',
#                 'untuk',
#                 'pria',
#                 'dua',
#                 'kategori',
#                 'untuk',
#                 'wanita',
#                 'dan',
#                 'satu',
#                 'kategori',
#                 'sepeda',
#                 'lipat',
#                 'untuk',
#                 'pria',
#                 'dapat',
#                 'kategori',
#                 'pendekar',
#                 'a',
#                 'untuk',
#                 'usia',
#                 '14-16',
#                 'tahun',
#                 'pendekar',
#                 'b',
#                 'usia',
#                 '17-18',
#                 'tahun',
#                 'pendekar',
#                 'c',
#                 'usia',
#                 '19-30',
#                 'tahun',
#                 'pendekar',
#                 'd',
#                 'usia',
#                 '31-40',
#                 'tahun',
#                 'pendekar',
#                 'e',
#                 'usia',
#                 '41-50',
#                 'tahun',
#                 'dan',
#                 'pendekar',
#                 'f',
#                 'usia',
#                 '50',
#                 'tahun',
#                 'ke',
#                 'atas',
#                 'sedang',
#                 'wanita',
#                 'dapat',
#                 'dua',
#                 'kategori',
#                 'yakni',
#                 'women',
#                 'junior',
#                 'usia',
#                 '14-30',
#                 'tahun',
#                 'dan',
#                 'kategori',
#                 'women',
#                 'open',
#                 'usia',
#                 'di',
#                 'atas',
#                 '31',
#                 'tahun',
#                 'masing-masing',
#                 'kategori',
#                 'ambil',
#                 'lima',
#                 'menang',
#                 'mana',
#                 'posisi',
#                 'pertama',
#                 'hak',
#                 'dapat',
#                 'gelar',
#                 'raja',
#                 'tanjak',
#                 'king',
#                 'of',
#                 'mountain',
#                 'kom',
#                 'atau',
#                 'queen',
#                 'of',
#                 'mountain',
#                 'qom',
#                 'saat',
#                 'mlc',
#                 '2022',
#                 'hari',
#                 'dua',
#                 'langsung',
#                 'serta',
#                 'ajak',
#                 'untuk',
#                 'nikmat',
#                 'wisata',
#                 'alam',
#                 'serta',
#                 'uni',
#                 'tiap',
#                 'wilayah',
#                 'yang',
#                 'lewat',
#                 'seperti',
#                 'lokasi',
#                 'start',
#                 'di',
#                 'balai',
#                 'kota',
#                 'madiun',
#                 'yang',
#                 'ada',
#                 'di',
#                 'kawasan',
#                 'pahlawan',
#                 'street',
#                 'center',
#                 'psc',
#                 'hingga',
#                 'lokasi',
#                 'lereng',
#                 'gunung',
#                 'lawu',
#                 'magetan',
#                 'yang',
#                 'dapat',
#                 'pandang',
#                 'telaga',
#                 'wahyu',
#                 'dan',
#                 'telaga',
#                 'sarangan',
#                 'agenda',
#                 'tahunanwali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'sebut',
#                 'ajang',
#                 'juara',
#                 'balap',
#                 'sepeda',
#                 'madiun',
#                 'lawu',
#                 'challenge',
#                 'mlc',
#                 'akan',
#                 'jadi',
#                 'agenda',
#                 'rutin',
#                 'yang',
#                 'gelar',
#                 'tiap',
#                 'tahun',
#                 'untuk',
#                 'dongkrak',
#                 'ekonomi',
#                 'dan',
#                 'wisata',
#                 'serta',
#                 'jaring',
#                 'potensi',
#                 'atlet',
#                 'ini',
#                 'salah',
#                 'satu',
#                 'awal',
#                 'yang',
#                 'baik',
#                 'ini',
#                 'beri',
#                 'semangat',
#                 'bagi',
#                 'kita',
#                 'semua',
#                 'untuk',
#                 'lebih',
#                 'riah',
#                 'lagi',
#                 'ke',
#                 'depan',
#                 'ujar',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'usai',
#                 'selenggara',
#                 'mlc',
#                 '2022',
#                 'wali',
#                 'kota',
#                 'sebut',
#                 'serta',
#                 'tampak',
#                 'puas',
#                 'dengan',
#                 'selenggara',
#                 'event',
#                 'sebut',
#                 'trek',
#                 'tanjak',
#                 'yang',
#                 'suguh',
#                 'tak',
#                 'hanya',
#                 'tantang',
#                 'namun',
#                 'hasil',
#                 'pacu',
#                 'adrenalin',
#                 'serta',
#                 'wali',
#                 'kota',
#                 'maidi',
#                 'kata',
#                 'event',
#                 'rupa',
#                 'akan',
#                 'gelar',
#                 'dengan',
#                 'lebih',
#                 'besar',
#                 'ke',
#                 'depan',
#                 'tahun',
#                 'depan',
#                 'kita',
#                 'buat',
#                 'lebih',
#                 'besar',
#                 'saya',
#                 'memang',
#                 'minta',
#                 'kritik',
#                 'dan',
#                 'saran',
#                 'kira',
#                 'apa',
#                 'yang',
#                 'kurang',
#                 'tadi',
#                 'sudah',
#                 'sempat',
#                 'muncul',
#                 'masuk',
#                 'mungkin',
#                 'nanti',
#                 'kita',
#                 'buat',
#                 'rute',
#                 'lebih',
#                 'panjang',
#                 'mungkin',
#                 'akan',
#                 'kita',
#                 'pola',
#                 'surabaya-madiun-cemoro',
#                 'sewu',
#                 'dari',
#                 'surabaya',
#                 'stay',
#                 'dulu',
#                 'malam',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'karena',
#                 'saya',
#                 'minta',
#                 'saran',
#                 'masuk',
#                 'agar',
#                 'lebih',
#                 'besar',
#                 'lagi',
#                 'kata',
#                 'pihak',
#                 'juga',
#                 'ucap',
#                 'terima',
#                 'kasih',
#                 'kepada',
#                 'semua',
#                 'pihak',
#                 'yang',
#                 'telah',
#                 'libat',
#                 'sehingga',
#                 'ajang',
#                 'mlc',
#                 '2022',
#                 'dapat',
#                 'langsung',
#                 'lancar',
#                 'aman',
#                 'dan',
#                 'riah',
#                 'ia',
#                 'tambah',
#                 'giat',
#                 'mlc',
#                 '2022',
#                 'yang',
#                 'ikut',
#                 'oleh',
#                 'ratus',
#                 'serta',
#                 'dari',
#                 'tanah',
#                 'air',
#                 'sebut',
#                 'harap',
#                 'juga',
#                 'bagai',
#                 'ajang',
#                 'promosi',
#                 'untuk',
#                 'menyebarluaskan',
#                 'informasi',
#                 'wisata',
#                 'kota',
#                 'madiun',
#                 'ke',
#                 'tingkat',
#                 'nasional',
#                 'dan',
#                 'juga',
#                 'internasional',
#                 'sehingga',
#                 'muara',
#                 'adalah',
#                 'dongkrak',
#                 'popularitas',
#                 'kota',
#                 'madiun',
#                 'bagai',
#                 'kota',
#                 'ramah',
#                 'sepeda',
#                 'yang',
#                 'akhir',
#                 'juga',
#                 'datang',
#                 'banyak',
#                 'wisatawan'],
#  'WordsStop': ['ajang',
#                'balap',
#                'sepeda',
#                'madiun',
#                'lawu',
#                'challenge',
#                'mlc',
#                '2022',
#                'lintas',
#                'wilayah',
#                'kota',
#                'madiun',
#                'jatim',
#                'balap',
#                'sepeda',
#                'jarak',
#                'tempuh',
#                '70',
#                'kilometer',
#                'start',
#                'balai',
#                'kota',
#                'madiun',
#                'finish',
#                'coro',
#                'sewu',
#                'magetan',
#                'jalur',
#                'tanjak',
#                'lereng',
#                'gunung',
#                'lawu',
#                '320',
#                'daerah',
#                'indonesia',
#                'mancanegara',
#                'ho-diskominfo',
#                'kota',
#                'madiun',
#                'ajang',
#                'balap',
#                'sepeda',
#                'madiun',
#                'lawu',
#                'challenge',
#                'mlc',
#                '2022',
#                'sesi',
#                'criterium',
#                'adu',
#                'sirkuit',
#                'jalan',
#                'raya',
#                'tutup',
#                'lintas',
#                'sedia',
#                'panitia',
#                'putar',
#                'jalan',
#                'mastrip',
#                'abdurahman',
#                'saleh',
#                'panglima',
#                'sudirman',
#                'stadion',
#                'wilis',
#                'kota',
#                'madiun',
#                'jatim',
#                'minggu',
#                '17',
#                '7',
#                '2022',
#                'ho-diskominfo',
#                'kota',
#                'madiun',
#                'madiun',
#                '-',
#                'juara',
#                'balap',
#                'sepeda',
#                'madiun',
#                'lawu',
#                'challenge',
#                'mlc',
#                '2022',
#                'gelar',
#                'jumat',
#                'tanggal',
#                '15',
#                'juli',
#                'resmi',
#                'minggu',
#                'tanggal',
#                '17',
#                'juli',
#                'selesai',
#                'euforia',
#                'bekas',
#                'benak',
#                'ratus',
#                'cyclist',
#                'ajang',
#                'kali',
#                'gelar',
#                'sukses',
#                'gaung',
#                'kota',
#                'madiun',
#                'lokasi',
#                'pusat',
#                'selenggara',
#                'kenal',
#                'kota',
#                'ramah',
#                'sepeda',
#                'mlc',
#                '2022',
#                'rupa',
#                'ajang',
#                'gabung',
#                'giat',
#                'olahraga',
#                'balap',
#                'sepeda',
#                'wisata',
#                'sport',
#                'tourism',
#                'harap',
#                'bawa',
#                'dampak',
#                'giat',
#                'promosi',
#                'wisata',
#                'kota',
#                'madiun',
#                'daerah',
#                'rute',
#                'ketua',
#                'ikat',
#                'sport',
#                'sepeda',
#                'indonesia',
#                'issi',
#                'kota',
#                'madiun',
#                'faizal',
#                'rachman',
#                'mlc',
#                '2022',
#                'buah',
#                'terobos',
#                'gagas',
#                'bumn',
#                'issi',
#                'kota',
#                'madiun',
#                'pemkot',
#                'madiun',
#                'mlc',
#                '2022',
#                'adalahsepeda',
#                'kemas',
#                'sport',
#                'tourism',
#                'olahraga',
#                'misi',
#                'prestasi',
#                'wisata',
#                'event',
#                'proyeksi',
#                'menjaditersebut',
#                'rupa',
#                'bentuk',
#                'dukung',
#                'hadap',
#                'program',
#                'wali',
#                'kota',
#                'madiun',
#                'ubah',
#                'kota',
#                'madiun',
#                'dongkrak',
#                'sektor',
#                'pariwisata',
#                'event',
#                'rupa',
#                'rangkai',
#                'kota',
#                'madiun',
#                'ke-104',
#                'ajak',
#                'kota',
#                'indonesia',
#                'mancanegara',
#                'partisipasi',
#                'takluk',
#                'tantang',
#                'rute',
#                'madiun-cemoro',
#                'sewu',
#                'pandang',
#                'eksotis',
#                'nikmat',
#                'indah',
#                'kota',
#                'madiun',
#                'rangkai',
#                'event',
#                'mlc',
#                '2022',
#                'gelar',
#                '3',
#                'tanggal',
#                '15-17',
#                'juli',
#                'pusat',
#                'kota',
#                'madiun',
#                'buka',
#                'fun',
#                'bike',
#                'sepeda',
#                'santai',
#                'wali',
#                'kota',
#                'madiun',
#                'rute',
#                'sepeda',
#                'wisata',
#                'jumat',
#                '15',
#                '7',
#                'kota',
#                'madiun',
#                'pesta',
#                'buka',
#                'kawasan',
#                'taman',
#                'sumber',
#                'wangi',
#                'pahlawan',
#                'street',
#                'center',
#                'psc',
#                'ratus',
#                'cyclist',
#                'ajak',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'forkopimda',
#                'nikmat',
#                'indah',
#                'tata',
#                'kota',
#                'madiun',
#                'ramah',
#                'sepeda',
#                'jalur',
#                'sepeda',
#                'wisata',
#                'batas',
#                'warga',
#                'tipe',
#                'sepeda',
#                'balap',
#                'sepeda',
#                'daftar',
#                'ajak',
#                'takluk',
#                'jalur',
#                'eksotis',
#                '70',
#                'kilometer',
#                'elevasi',
#                '1',
#                '800',
#                'meter',
#                'rute',
#                'madiun-cemoro',
#                'sewu',
#                'start',
#                'balai',
#                'kota',
#                'madiun',
#                'finish',
#                'coro',
#                'sewu',
#                'magetan',
#                'adu',
#                'cepat',
#                'sesi',
#                'criterium',
#                'minggu',
#                '17',
#                '7',
#                'kelas',
#                'tanding',
#                'usia',
#                'ajar',
#                'atlet',
#                'hobbies',
#                'mantan',
#                'atlet',
#                'ajang',
#                'mlc',
#                '2022',
#                'rute',
#                'madiun-cemoro',
#                'sewu',
#                'magetan',
#                '320',
#                'daerah',
#                'tanah',
#                'air',
#                'mancanegara',
#                'inggris',
#                'italia',
#                'swiss',
#                'sembilan',
#                'kategori',
#                'ajang',
#                'mlc',
#                '2022',
#                'rute',
#                'madiun-cemoro',
#                'sewu',
#                'magetan',
#                'enam',
#                'kategori',
#                'pria',
#                'kategori',
#                'wanita',
#                'kategori',
#                'sepeda',
#                'lipat',
#                'pria',
#                'kategori',
#                'pendekar',
#                'a',
#                'usia',
#                '14-16',
#                'pendekar',
#                'b',
#                'usia',
#                '17-18',
#                'pendekar',
#                'c',
#                'usia',
#                '19-30',
#                'pendekar',
#                'd',
#                'usia',
#                '31-40',
#                'pendekar',
#                'e',
#                'usia',
#                '41-50',
#                'pendekar',
#                'f',
#                'usia',
#                '50',
#                'wanita',
#                'kategori',
#                'women',
#                'junior',
#                'usia',
#                '14-30',
#                'kategori',
#                'women',
#                'open',
#                'usia',
#                '31',
#                'kategori',
#                'ambil',
#                'menang',
#                'posisi',
#                'hak',
#                'gelar',
#                'raja',
#                'tanjak',
#                'king',
#                'of',
#                'mountain',
#                'kom',
#                'queen',
#                'of',
#                'mountain',
#                'qom',
#                'mlc',
#                '2022',
#                'langsung',
#                'ajak',
#                'nikmat',
#                'wisata',
#                'alam',
#                'uni',
#                'wilayah',
#                'lokasi',
#                'start',
#                'balai',
#                'kota',
#                'madiun',
#                'kawasan',
#                'pahlawan',
#                'street',
#                'center',
#                'psc',
#                'lokasi',
#                'lereng',
#                'gunung',
#                'lawu',
#                'magetan',
#                'pandang',
#                'telaga',
#                'wahyu',
#                'telaga',
#                'sarangan',
#                'agenda',
#                'tahunanwali',
#                'kota',
#                'madiun',
#                'maidi',
#                'ajang',
#                'juara',
#                'balap',
#                'sepeda',
#                'madiun',
#                'lawu',
#                'challenge',
#                'mlc',
#                'agenda',
#                'rutin',
#                'gelar',
#                'dongkrak',
#                'ekonomi',
#                'wisata',
#                'jaring',
#                'potensi',
#                'atlet',
#                'salah',
#                'semangat',
#                'riah',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'selenggara',
#                'mlc',
#                '2022',
#                'wali',
#                'kota',
#                'puas',
#                'selenggara',
#                'event',
#                'trek',
#                'tanjak',
#                'suguh',
#                'tantang',
#                'hasil',
#                'pacu',
#                'adrenalin',
#                'wali',
#                'kota',
#                'maidi',
#                'event',
#                'rupa',
#                'gelar',
#                'kritik',
#                'saran',
#                'muncul',
#                'masuk',
#                'rute',
#                'pola',
#                'surabaya-madiun-cemoro',
#                'sewu',
#                'surabaya',
#                'stay',
#                'malam',
#                'kota',
#                'madiun',
#                'saran',
#                'masuk',
#                'terima',
#                'kasih',
#                'libat',
#                'ajang',
#                'mlc',
#                '2022',
#                'langsung',
#                'lancar',
#                'aman',
#                'riah',
#                'giat',
#                'mlc',
#                '2022',
#                'ratus',
#                'tanah',
#                'air',
#                'harap',
#                'ajang',
#                'promosi',
#                'menyebarluaskan',
#                'informasi',
#                'wisata',
#                'kota',
#                'madiun',
#                'tingkat',
#                'nasional',
#                'internasional',
#                'muara',
#                'dongkrak',
#                'popularitas',
#                'kota',
#                'madiun',
#                'kota',
#                'ramah',
#                'sepeda',
#                'wisatawan']}
# {'Article': 'Para peserta ajang balap sepeda Madiun Lawu Challenge (MLC) 2022 '
#             'melintas di wilayah Kota Madiun, Jatim. Balap sepeda dengan jarak '
#             'tempuh sekitar 70 kilometer start dari Balai Kota Madiun dan '
#             'finish di Cemoro Sewu Magetan yang sebagian besar jalurnya '
#             'melewati tanjakan lereng Gunung Lawu tersebut diikuti 320 peserta '
#             'dari berbagai daerah di Indonesia dan beberapa peserta dari '
#             'mancanegara. (ANTARA/HO-Diskominfo Kota Madiun)\n'
#             '\n'
#             'Para peserta ajang balap sepeda Madiun Lawu Challenge (MLC) 2022 '
#             'sesi Criterium beradu di sirkuit jalan raya tertutup dari lalu '
#             'lintas umum yang telah disediakan panitia, yakni di seputaran '
#             'Jalan Mastrip, Abdurahman Saleh, Panglima Sudirman, dan Stadion '
#             'Wilis Kota Madiun, Jatim, Minggu (17/7/2022). '
#             'katanya.Adapun, rangkaian event MLC 2022 digelar selama 3 hari '
#             'tanggal 15-17 Juli berpusat di Kota Madiun.\n'
#             'Hari pertama, dibuka dengan "fun bike" atau sepeda santai bersama '
#             'Wali Kota Madiun dengan rute sepeda wisata pada Jumat (15/7) di '
#             'Kota Madiun.\n'
#             'Dari Surabaya "stay" dulu semalam di Kota Madiun.',
#  'Time': 'Sun, 17 Jul 2022 16:50:59 GMT',
#  'Title': 'Madiun Lawu Challenge (MLC) 2022 ajang promosi wisata ke tingkat '
#           'internasional - ANTARA Jawa Timur',
#  'TotalKata': 522,
#  'WordTokens': ['para',
#                 'serta',
#                 'ajang',
#                 'balap',
#                 'sepeda',
#                 'madiun',
#                 'lawu',
#                 'challenge',
#                 'mlc',
#                 '2022',
#                 'lintas',
#                 'di',
#                 'wilayah',
#                 'kota',
#                 'madiun',
#                 'jatim',
#                 'balap',
#                 'sepeda',
#                 'dengan',
#                 'jarak',
#                 'tempuh',
#                 'sekitar',
#                 '70',
#                 'kilometer',
#                 'start',
#                 'dari',
#                 'balai',
#                 'kota',
#                 'madiun',
#                 'dan',
#                 'finish',
#                 'di',
#                 'coro',
#                 'sewu',
#                 'magetan',
#                 'yang',
#                 'bagi',
#                 'besar',
#                 'jalur',
#                 'lewat',
#                 'tanjak',
#                 'lereng',
#                 'gunung',
#                 'lawu',
#                 'sebut',
#                 'ikut',
#                 '320',
#                 'serta',
#                 'dari',
#                 'bagai',
#                 'daerah',
#                 'di',
#                 'indonesia',
#                 'dan',
#                 'beberapa',
#                 'serta',
#                 'dari',
#                 'mancanegara',
#                 'antara',
#                 'ho-diskominfo',
#                 'kota',
#                 'madiun',
#                 'para',
#                 'serta',
#                 'ajang',
#                 'balap',
#                 'sepeda',
#                 'madiun',
#                 'lawu',
#                 'challenge',
#                 'mlc',
#                 '2022',
#                 'sesi',
#                 'criterium',
#                 'adu',
#                 'di',
#                 'sirkuit',
#                 'jalan',
#                 'raya',
#                 'tutup',
#                 'dari',
#                 'lalu',
#                 'lintas',
#                 'umum',
#                 'yang',
#                 'telah',
#                 'sedia',
#                 'panitia',
#                 'yakni',
#                 'di',
#                 'putar',
#                 'jalan',
#                 'mastrip',
#                 'abdurahman',
#                 'saleh',
#                 'panglima',
#                 'sudirman',
#                 'dan',
#                 'stadion',
#                 'wilis',
#                 'kota',
#                 'madiun',
#                 'jatim',
#                 'minggu',
# ...
#             'pertandingan uji coba tersebut. Namun, dengan berbagai '
#             'persyaratan. Salah satunya, harus menjaga keamanan dan ketertiban '
#             'di Kota Madiun.\n'
#             '\n'
#             '‘’Aman itu mahal. Silahkan digunakan tetapi harus dipastikan '
#             'keamanan dan ketertiban terjaga dengan baik. Harus siap '
#             'bertanggung jawab kalau terjadi hal-hal yang tidak kita '
#             'inginkan,’’ ungkapnya.\n'
#             '\n'
#             'Wali kota mengapresiasi kepada manajemen Persik Kediri maupun '
#             'setiap tim lawan yang datang. Sebab, semua pertandingan berjalan '
#             'dengan baik. Masing-masing pihak bisa menjunjung tinggi '
#             'sportivitas serta menjaga keamanan dan ketertiban. Selain itu, '
#             'wali kota tak memungkiri hadirnya sejumlah pertandingan tersebut '
#             'juga mendongkrak perekonomian Kota Madiun. Paling tidak, mereka '
#             'yang datang membutuhkan makanan dan minuman. Artinya, mereka '
#             'berbelanja di Kota Madiun.\n'
#             '\n'
#             '‘’Nanti akan kita skemakan event-event olahraga rutin tiap-tiap '
#             'cabor paling tidak sebulan sekali. Ini untuk meramaikan kota kita '
#             'sekaligus ajang pembinaan dan pembibitan atlet-atlet kita,’’ '
#             'pungkasnya. (nanda/agi/diskominfo)',
#  'Read more': 'https://madiuntoday.id/2022/07/17/saksikan-persik-kediri-vs-persis-solo-wali-kota-apresiasi-sportivitas-kedua-tim/',
#  'Sentiment': 'netral',
#  'Stemming': 'madiun wali kota madiun maidi kembali saksi tanding uji coba '
#              'persik diri di stadion wilis madiun minggu 17 7 orang nomor satu '
#              'di kota pendekar itu tampak nikmat jalan tanding persik yang '
#              'jamu persis solo sebut tak hanya ikut tanding wali kota juga '
#              'pasti stadion wilis nyaman dan aman bagai tempat tanding sepak '
#              'bola kelas liga satu kendati hanya uji coba kita punya stadion '
#              'yang bagus stadion yang cukup layak untuk gelar tanding seperti '
#              'ini kita harus bangga kata wali kota seperti tahu persik diri '
#              'jadi stadion wilis untuk jumlah tanding uji coba belum kick off '
#              'liga 1 gulir hal itu karena stadion stadion brawijaya yang '
#              'tengah renovasi wali kota tidak dua kali saksi langsung tanding '
#              'persik di stadion wilis salah satu saat jamu persis solo yang '
#              'sudah sama kuat 1-1 sebut wali kota maidi memang beri lampu '
#              'hijau kepada persik untuk jumlah tanding uji coba sebut namun '
#              'dengan bagai syarat salah satu harus jaga aman dan tertib di '
#              'kota madiun aman itu mahal silah guna tetapi harus pasti aman '
#              'dan tertib jaga dengan baik harus siap tanggung jawab kalau jadi '
#              'hal yang tidak kita ingin ungkap wali kota apresiasi kepada '
#              'manajemen persik diri maupun tiap tim lawan yang datang sebab '
#              'semua tanding jalan dengan baik masing-masing pihak bisa junjung '
#              'tinggi sportivitas serta jaga aman dan tertib selain itu wali '
#              'kota tak mungkir hadir jumlah tanding sebut juga dongkrak '
#              'ekonomi kota madiun paling tidak mereka yang datang butuh makan '
#              'dan minum arti mereka belanja di kota madiun nanti akan kita '
#              'skema event-event olahraga rutin tiap cabor paling tidak bulan '
#              'sekali ini untuk ramai kota kita sekaligus ajang bina dan bibit '
#              'atlet kita pungkas nanda agi diskominfo',
#  'Summary': 'MADIUN – Wali Kota Madiun, Maidi kembali menyaksikan pertandingan '
#             'uji coba Persik Kediri di Stadion Wilis Madiun, Minggu (17/7).\n'
#             'Orang nomor satu di Kota Pendekar itu tampak menikmati jalannya '
#             'pertandingan Persik yang menjamu Persis Solo tersebut.\n'
#             'Tak hanya mengikuti pertandingan, wali kota juga memastikan '
#             'Stadion Wilis nyaman dan aman sebagai tempat pertandingan sepak '
#             'bola sekelas liga satu kendati hanya uji coba.\n'
#             'Wali kota setidaknya dua kali menyaksikan langsung pertandingan '
#             'Persik di Stadion Wilis.\n'
#             'Wali kota mengapresiasi kepada manajemen Persik Kediri maupun '
#             'setiap tim lawan yang datang.',
#  'Time': 'Sun, 17 Jul 2022 13:25:39 GMT',
#  'Title': 'Saksikan Persik Kediri Vs Persis Solo, Wali Kota Apresiasi '
#           'Sportivitas Kedua Tim | - madiuntoday',
#  'TotalKata': 149,
#  'WordTokens': ['madiun',
#                 'wali',
#                 'kota',
#                 'madiun',
#                 'maidi',
#                 'kembali',
#                 'saksi',
#                 'tanding',
#                 'uji',
#                 'coba',
#                 'persik',
#                 'diri',
#                 'di',
#                 'stadion',
#                 'wilis',
#                 'madiun',
#                 'minggu',
#                 '17',
#                 '7',
#                 'orang',
#                 'nomor',
#                 'satu',
#                 'di',
#                 'kota',
#                 'pendekar',
#                 'itu',
#                 'tampak',
#                 'nikmat',
#                 'jalan',
#                 'tanding',
#                 'persik',
#                 'yang',
#                 'jamu',
#                 'persis',
#                 'solo',
#                 'sebut',
#                 'tak',
#                 'hanya',
#                 'ikut',
#                 'tanding',
#                 'wali',
#                 'kota',
#                 'juga',
#                 'pasti',
#                 'stadion',
#                 'wilis',
#                 'nyaman',
#                 'dan',
#                 'aman',
#                 'bagai',
#                 'tempat',
#                 'tanding',
#                 'sepak',
#                 'bola',
#                 'kelas',
#                 'liga',
#                 'satu',
#                 'kendati',
#                 'hanya',
#                 'uji',
#                 'coba',
#                 'kita',
#                 'punya',
#                 'stadion',
#                 'yang',
#                 'bagus',
#                 'stadion',
#                 'yang',
#                 'cukup',
#                 'layak',
#                 'untuk',
#                 'gelar',
#                 'tanding',
#                 'seperti',
#                 'ini',
#                 'kita',
#                 'harus',
#                 'bangga',
#                 'kata',
#                 'wali',
#                 'kota',
#                 'seperti',
#                 'tahu',
#                 'persik',
#                 'diri',
#                 'jadi',
#                 'stadion',
#                 'wilis',
#                 'untuk',
#                 'jumlah',
#                 'tanding',
#                 'uji',
#                 'coba',
#                 'belum',
#                 'kick',
#                 'off',
#                 'liga',
#                 '1',
#                 'gulir',
#                 'hal',
#                 'itu',
#                 'karena',
#                 'stadion',
#                 'stadion',
#                 'brawijaya',
#                 'yang',
#                 'tengah',
#                 'renovasi',
#                 'wali',
#                 'kota',
#                 'tidak',
#                 'dua',
#                 'kali',
#                 'saksi',
#                 'langsung',
#                 'tanding',
#                 'persik',
#                 'di',
#                 'stadion',
#                 'wilis',
#                 'salah',
#                 'satu',
#                 'saat',
#                 'jamu',
#                 'persis',
#                 'solo',
#                 'yang',
#                 'sudah',
#                 'sama',
#                 'kuat',
#                 '1-1',
#                 'sebut',
#                 'wali',
#                 'kota',
#                 'maidi',
#                 'memang',
#                 'beri',
#                 'lampu',
#                 'hijau',
#                 'kepada',
#                 'persik',
#                 'untuk',
#                 'jumlah',
#                 'tanding',
#                 'uji',
#                 'coba',
#                 'sebut',
#                 'namun',
#                 'dengan',
#                 'bagai',
#                 'syarat',
#                 'salah',
#                 'satu',
#                 'harus',
#                 'jaga',
#                 'aman',
#                 'dan',
#                 'tertib',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'aman',
#                 'itu',
#                 'mahal',
#                 'silah',
#                 'guna',
#                 'tetapi',
#                 'harus',
#                 'pasti',
#                 'aman',
#                 'dan',
#                 'tertib',
#                 'jaga',
#                 'dengan',
#                 'baik',
#                 'harus',
#                 'siap',
#                 'tanggung',
#                 'jawab',
#                 'kalau',
#                 'jadi',
#                 'hal',
#                 'yang',
#                 'tidak',
#                 'kita',
#                 'ingin',
#                 'ungkap',
#                 'wali',
#                 'kota',
#                 'apresiasi',
#                 'kepada',
#                 'manajemen',
#                 'persik',
#                 'diri',
#                 'maupun',
#                 'tiap',
#                 'tim',
#                 'lawan',
#                 'yang',
#                 'datang',
#                 'sebab',
#                 'semua',
#                 'tanding',
#                 'jalan',
#                 'dengan',
#                 'baik',
#                 'masing-masing',
#                 'pihak',
#                 'bisa',
#                 'junjung',
#                 'tinggi',
#                 'sportivitas',
#                 'serta',
#                 'jaga',
#                 'aman',
#                 'dan',
#                 'tertib',
#                 'selain',
#                 'itu',
#                 'wali',
#                 'kota',
#                 'tak',
#                 'mungkir',
#                 'hadir',
#                 'jumlah',
#                 'tanding',
#                 'sebut',
#                 'juga',
#                 'dongkrak',
#                 'ekonomi',
#                 'kota',
#                 'madiun',
#                 'paling',
#                 'tidak',
#                 'mereka',
#                 'yang',
#                 'datang',
#                 'butuh',
#                 'makan',
#                 'dan',
#                 'minum',
#                 'arti',
#                 'mereka',
#                 'belanja',
#                 'di',
#                 'kota',
#                 'madiun',
#                 'nanti',
#                 'akan',
#                 'kita',
#                 'skema',
#                 'event-event',
#                 'olahraga',
#                 'rutin',
#                 'tiap',
#                 'cabor',
#                 'paling',
#                 'tidak',
#                 'bulan',
#                 'sekali',
#                 'ini',
#                 'untuk',
#                 'ramai',
#                 'kota',
#                 'kita',
#                 'sekaligus',
#                 'ajang',
#                 'bina',
#                 'dan',
#                 'bibit',
#                 'atlet',
#                 'kita',
#                 'pungkas',
#                 'nanda',
#                 'agi',
#                 'diskominfo'],
#  'WordsStop': ['madiun',
#                'wali',
#                'kota',
#                'madiun',
#                'maidi',
#                'saksi',
#                'tanding',
#                'uji',
#                'coba',
#                'persik',
#                'stadion',
#                'wilis',
#                'madiun',
#                'minggu',
#                '17',
#                '7',
#                'orang',
#                'nomor',
#                'kota',
#                'pendekar',
#                'nikmat',
#                'jalan',
#                'tanding',
#                'persik',
#                'jamu',
#                'persis',
#                'solo',
#                'tanding',
#                'wali',
#                'kota',
#                'stadion',
#                'wilis',
#                'nyaman',
#                'aman',
#                'tanding',
#                'sepak',
#                'bola',
#                'kelas',
#                'liga',
#                'kendati',
#                'uji',
#                'coba',
#                'stadion',
#                'bagus',
#                'stadion',
#                'layak',
#                'gelar',
#                'tanding',
#                'bangga',
#                'wali',
#                'kota',
#                'persik',
#                'stadion',
#                'wilis',
#                'tanding',
#                'uji',
#                'coba',
#                'kick',
#                'off',
#                'liga',
#                '1',
#                'gulir',
#                'stadion',
#                'stadion',
#                'brawijaya',
#                'renovasi',
#                'wali',
#                'kota',
#                'kali',
#                'saksi',
#                'langsung',
#                'tanding',
#                'persik',
#                'stadion',
#                'wilis',
#                'salah',
#                'jamu',
#                'persis',
#                'solo',
#                'kuat',
#                '1-1',
#                'wali',
#                'kota',
#                'maidi',
#                'lampu',
#                'hijau',
#                'persik',
#                'tanding',
#                'uji',
#                'coba',
#                'syarat',
#                'salah',
#                'jaga',
#                'aman',
#                'tertib',
#                'kota',
#                'madiun',
#                'aman',
#                'mahal',
#                'silah',
#                'aman',
#                'tertib',
#                'jaga',
#                'tanggung',
#                'wali',
#                'kota',
#                'apresiasi',
#                'manajemen',
#                'persik',
#                'tim',
#                'lawan',
#                'tanding',
#                'jalan',
#                'junjung',
#                'sportivitas',
#                'jaga',
#                'aman',
#                'tertib',
#                'wali',
#                'kota',
#                'mungkir',
#                'hadir',
#                'tanding',
#                'dongkrak',
#                'ekonomi',
#                'kota',
#                'madiun',
#                'butuh',
#                'makan',
#                'minum',
#                'arti',
#                'belanja',
#                'kota',
#                'madiun',
#                'skema',
#                'event-event',
#                'olahraga',
#                'rutin',
#                'cabor',
#                'ramai',
#                'kota',
#                'ajang',
#                'bina',
#                'bibit',
#                'atlet',
#                'pungkas',
#                'nanda',
#                'agi',
#                'diskominfo']}
# {'Article': '',
#  'Read more': 'https://www.harianbhirawa.co.id/wali-kota-madiun-harap-okupansi-rumah-sakit-semakin-turun/',
#  'Sentiment': 'netral',
#  'Stemming': '',
#  'Summary': '',
#  'Time': 'Sun, 17 Jul 2022 14:12:09 GMT',
#  'Title': 'Wali Kota Madiun Harap Okupansi Rumah Sakit Semakin Turun - Harian '
#           'Bhirawa',
#  'TotalKata': 0,
#  'WordTokens': [],
#  'WordsStop': []}
# {'Article': '',
#  'Read more': 'https://www.harianbhirawa.co.id/wali-kota-madiun-harap-okupansi-rumah-sakit-semakin-turun/',
#  'Sentiment': 'netral',
#  'Stemming': '',
#  'Summary': '',
#  'Time': 'Sun, 17 Jul 2022 14:12:09 GMT',
#  'Title': 'Wali Kota Madiun Harap Okupansi Rumah Sakit Semakin Turun - Harian '
#           'Bhirawa',
#  'TotalKata': 0,
#  'WordTokens': [],
#  'WordsStop': []}
# Download news_today.txt Sucessfully
# Download news_today.csv Sucessfully
# Now Enter Your Topics to Search or Exit: Exit
# See you, hope you have a great day! ❤️

# %%
# Python program to generate WordCloud
 
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv((input('Masukkan file: ')), encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.WordsStop:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
# Out:
# Masukkan file: madiun.csv
